# %% [markdown]
# 作者：云朵君
# 公众号：数据STUDIO
# 代码仓促整理，若有问题，请及时联系云朵君

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['font.family'] = ['Arial Unicode MS']#显示中文,解决图中无法显示中文的问题
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# # 数据清洗

# %% [markdown]
# ## 导入数据

# %%
data = pd.read_table('userlostprob.txt')
data.head()
# Out:
#    label  sampleid           d     arrival  iforderpv_24h  decisionhabit_user  \
# 0      0     24636  2016-05-18  2016-05-18              0                 NaN
# 1      1     24637  2016-05-18  2016-05-18              0                 NaN
# 2      0     24641  2016-05-18  2016-05-19              0                 NaN
# 3      0     24642  2016-05-18  2016-05-18              0                 NaN
# 4      1     24644  2016-05-18  2016-05-19              0                 NaN
#
#    historyvisit_7ordernum  historyvisit_totalordernum  hotelcr  \
# 0                     NaN                         NaN     1.04
# 1                     NaN                         NaN     1.06
# 2                     NaN                         NaN     1.05
# 3                     NaN                         NaN     1.01
# 4                     NaN                         NaN     1.00
#
#    ordercanceledprecent  ...  lowestprice_pre2  lasthtlordergap  \
# 0                   NaN  ...             615.0              NaN
# 1                   NaN  ...             513.0              NaN
# 2                   NaN  ...             382.0              NaN
# 3                   NaN  ...             203.0              NaN
# 4                   NaN  ...              84.0              NaN
#
#    businessrate_pre2  cityuvs  cityorders  lastpvgap  cr  sid  \
# 0               0.29   12.880       3.147        NaN NaN    7
# 1               0.53   17.933       4.913        NaN NaN   33
# 2               0.60    3.993       0.760        NaN NaN   10
# 3               0.18    3.220       0.660        NaN NaN    8
# 4                NaN    0.013         NaN        NaN NaN    1
#
#    visitnum_oneyear   h
# 0               NaN  12
# 1               NaN  14
# 2               NaN  19
# 3               NaN  16
# 4               NaN  21
#
# [5 rows x 51 columns]

# %% [markdown]
# ## 数据探索分析

# %%
data.shape
# Out:
# (689945, 51)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689945 entries, 0 to 689944
# Data columns (total 51 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   label                             689945 non-null  int64
#  1   sampleid                          689945 non-null  int64
#  2   d                                 689945 non-null  object
#  3   arrival                           689945 non-null  object
#  4   iforderpv_24h                     689945 non-null  int64
#  5   decisionhabit_user                385450 non-null  float64
#  6   historyvisit_7ordernum            82915 non-null   float64
#  7   historyvisit_totalordernum        386525 non-null  float64
#  8   hotelcr                           689148 non-null  float64
#  9   ordercanceledprecent              447831 non-null  float64
#  10  landhalfhours                     661312 non-null  float64
#  11  ordercanncelednum                 447831 non-null  float64
#  12  commentnums                       622029 non-null  float64
#  13  starprefer                        464892 non-null  float64
#  14  novoters                          672918 non-null  float64
#  15  consuming_capacity                463837 non-null  float64
#  16  historyvisit_avghotelnum          387876 non-null  float64
#  17  cancelrate                        678227 non-null  float64
#  18  historyvisit_visit_detailpagenum  307234 non-null  float64
#  19  delta_price1                      437146 non-null  float64
#  20  price_sensitive                   463837 non-null  float64
#  21  hoteluv                           689148 non-null  float64
#  22  businessrate_pre                  483896 non-null  float64
#  23  ordernum_oneyear                  447831 non-null  float64
#  24  cr_pre                            660548 non-null  float64
#  25  avgprice                          457261 non-null  float64
#  26  lowestprice                       687931 non-null  float64
#  27  firstorder_bu                     376993 non-null  float64
#  28  customereval_pre2                 661312 non-null  float64
#  29  delta_price2                      437750 non-null  float64
#  30  commentnums_pre                   598368 non-null  float64
#  31  customer_value_profit             439123 non-null  float64
#  32  commentnums_pre2                  648457 non-null  float64
#  33  cancelrate_pre                    653015 non-null  float64
#  34  novoters_pre2                     657616 non-null  float64
#  35  novoters_pre                      648956 non-null  float64
#  36  ctrip_profits                     445187 non-null  float64
#  37  deltaprice_pre2_t1                543180 non-null  float64
#  38  lowestprice_pre                   659689 non-null  float64
#  39  uv_pre                            660548 non-null  float64
#  40  uv_pre2                           661189 non-null  float64
#  41  lowestprice_pre2                  660664 non-null  float64
#  42  lasthtlordergap                   447831 non-null  float64
#  43  businessrate_pre2                 602960 non-null  float64
#  44  cityuvs                           682274 non-null  float64
#  45  cityorders                        651263 non-null  float64
#  46  lastpvgap                         592818 non-null  float64
#  47  cr                                457896 non-null  float64
#  48  sid                               689945 non-null  int64
#  49  visitnum_oneyear                  592910 non-null  float64
#  50  h                                 689945 non-null  int64
# dtypes: float64(44), int64(5), object(2)
# memory usage: 268.5+ MB

# %% [markdown]
# | 字段                             | 解释                                      |
# | -------------------------------- | ----------------------------------------- |
# | sampleid                         | 样本id                                    |
# | label                            | 目标变量                                  |
# | d                                | 访问日期                                  |
# | arrival                          | 入住日期                                  |
# | iforderpv_24h                    | 24小时内是否访问订单填写页                |
# | decisionhabit_user               | 决策习惯：以用户为单位观察决策习惯        |
# | historyvisit_7ordernum           | 近7天用户历史订单数                       |
# | historyvisit_totalordernum       | 近1年用户历史订单数                       |
# | hotelcr                          | 当前酒店历史cr                            |
# | ordercanceledprecent             | 用户一年内取消订单率                      |
# | landhalfhours                    | 24小时内登陆时长                          |
# | ordercanncelednum                | 用户一年内取消订单数                      |
# | commentnums                      | 当前酒店点评数                            |
# | starprefer                       | 星级偏好                                  |
# | novoters                         | 当前酒店评分人数                          |
# | consuming_capacity               | 消费能力指数                              |
# | historyvisit_avghotelnum         | 近3个月用户历史日均访问酒店数             |
# | cancelrate                       | 当前酒店历史取消率                        |
# | historyvisit_visit_detailpagenum | 7天内访问酒店详情页数                     |
# | delta_price1                     | 用户偏好价格-24小时浏览最多酒店价格       |
# | price_sensitive                  | 价格敏感指数                              |
# | hoteluv                          | 当前酒店历史uv                            |
# | businessrate_pre                 | 24小时历史浏览次数最多酒店商务属性指数    |
# | ordernum_oneyear                 | 用户年订单数                              |
# | cr_pre                           | 24小时历史浏览次数最多酒店历史cr          |
# | avgprice                         | 平均价格                                  |
# | lowestprice                      | 当前酒店可定最低价                        |
# | firstorder_bu                    | 首单bu                                    |
# | customereval_pre2                | 24小时历史浏览酒店客户评分均值            |
# | delta_price2                     | 用户偏好价格-24小时浏览酒店平均价格       |
# | commentnums_pre                  | 24小时历史浏览次数最多酒店点评数          |
# | customer_value_profit            | 客户价值_近1年                            |
# | commentnums_pre2                 | 24小时历史浏览酒店点评数均值              |
# | cancelrate_pre                   | 24小时内已访问次数最多酒店历史取消率      |
# | novoters_pre2                    | 24小时历史浏览酒店评分人数均值            |
# | novoters_pre                     | 24小时历史浏览次数最多酒店评分人数        |
# | ctrip_profits                    | 客户价值                                  |
# | deltaprice_pre2_t1               | 24小时内已访问酒店价格与对手价差均值，t+1 |
# | lowestprice_pre                  | 24小时内已访问次数最多酒店可订最低价      |
# | uv_pre                           | 24小时历史浏览次数最多酒店历史uv          |
# | uv_pre2                          | 24小时历史浏览酒店历史uv均值              |
# | lowestprice_pre2                 | 24小时内已访问酒店可订最低价均值          |
# | lasthtlordergap                  | 一年内距离上次下单时长                    |
# | businessrate_pre2                | 24小时内已访问酒店商务属性指数均值        |
# | cityuvs                          | 昨日访问当前城市同入住日期的app  uv数     |
# | cityorders                       | 昨日提交当前城市同入住日期的app订单数     |
# | lastpvgap                        | 一年内距上次访问时长                      |
# | cr                               | 用户转化率                                |
# | sid                              | 会话id，sid=1可认为是新访                 |
# | visitnum_oneyear                 | 年访问次数                                |
# | h                                | 访问时间点                                |

# %% [markdown]
# ### 重复值

# %%
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (689945, 51)

# %% [markdown]
# ### 缺失值

# %% [markdown]
# **查看缺失值比例，并排序**

# %%
null_ = data.isna().mean().reset_index().sort_values(by=0)

null_1 = null_.rename(columns={'index':'特征',0:'缺失比'}).reset_index(drop=True)

# %%
null_1
# Out:
#                                   特征       缺失比
# 0                              label  0.000000
# 1                                sid  0.000000
# 2                      iforderpv_24h  0.000000
# 3                                  h  0.000000
# 4                                  d  0.000000
# 5                           sampleid  0.000000
# 6                            arrival  0.000000
# 7                            hotelcr  0.001155
# 8                            hoteluv  0.001155
# 9                        lowestprice  0.002919
# 10                           cityuvs  0.011118
# 11                        cancelrate  0.016984
# 12                          novoters  0.024679
# 13                 customereval_pre2  0.041500
# 14                     landhalfhours  0.041500
# 15                           uv_pre2  0.041679
# 16                  lowestprice_pre2  0.042440
# 17                            uv_pre  0.042608
# 18                            cr_pre  0.042608
# 19                   lowestprice_pre  0.043853
# 20                     novoters_pre2  0.046857
# 21                    cancelrate_pre  0.053526
# 22                        cityorders  0.056065
# 23                      novoters_pre  0.059409
# 24                  commentnums_pre2  0.060132
# 25                       commentnums  0.098437
# 26                 businessrate_pre2  0.126075
# 27                   commentnums_pre  0.132731
# 28                  visitnum_oneyear  0.140642
# 29                         lastpvgap  0.140775
# 30                deltaprice_pre2_t1  0.212720
# 31                  businessrate_pre  0.298646
# 32                        starprefer  0.326190
# 33                   price_sensitive  0.327719
# 34                consuming_capacity  0.327719
# 35                                cr  0.336330
# 36                          avgprice  0.337250
# 37                  ordernum_oneyear  0.350918
# 38                   lasthtlordergap  0.350918
# 39                 ordercanncelednum  0.350918
# 40              ordercanceledprecent  0.350918
# 41                     ctrip_profits  0.354750
# 42             customer_value_profit  0.363539
# 43                      delta_price2  0.365529
# 44                      delta_price1  0.366405
# 45          historyvisit_avghotelnum  0.437816
# 46        historyvisit_totalordernum  0.439774
# 47                decisionhabit_user  0.441332
# 48                     firstorder_bu  0.453590
# 49  historyvisit_visit_detailpagenum  0.554698
# 50            historyvisit_7ordernum  0.879824

# %%
import seaborn as sns

# %%
plt.figure(figsize=(8,6))
sns.kdeplot(null_1['缺失比'],shade=True)
# Out:
# C:\Users\caoyuanyuan\AppData\Local\Temp\ipykernel_12588\2402435513.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(null_1['缺失比'],shade=True)
# <AxesSubplot: xlabel='缺失比', ylabel='Density'>

# %%
plt.figure(figsize=(8,6))
plt.barh(range(null_1.shape[0]),null_1['缺失比'],label='缺失比')
plt.legend(loc=4)
plt.ylabel('特征变量',fontsize=15);

# %%
null_.rename(columns={'index':'特征',0:'缺失比'}).set_index('特征')
# Out:
#                                        缺失比
# 特征
# label                             0.000000
# sid                               0.000000
# iforderpv_24h                     0.000000
# h                                 0.000000
# d                                 0.000000
# sampleid                          0.000000
# arrival                           0.000000
# hotelcr                           0.001155
# hoteluv                           0.001155
# lowestprice                       0.002919
# cityuvs                           0.011118
# cancelrate                        0.016984
# novoters                          0.024679
# customereval_pre2                 0.041500
# landhalfhours                     0.041500
# uv_pre2                           0.041679
# lowestprice_pre2                  0.042440
# uv_pre                            0.042608
# cr_pre                            0.042608
# lowestprice_pre                   0.043853
# novoters_pre2                     0.046857
# cancelrate_pre                    0.053526
# cityorders                        0.056065
# novoters_pre                      0.059409
# commentnums_pre2                  0.060132
# commentnums                       0.098437
# businessrate_pre2                 0.126075
# commentnums_pre                   0.132731
# visitnum_oneyear                  0.140642
# lastpvgap                         0.140775
# deltaprice_pre2_t1                0.212720
# businessrate_pre                  0.298646
# starprefer                        0.326190
# price_sensitive                   0.327719
# consuming_capacity                0.327719
# cr                                0.336330
# avgprice                          0.337250
# ordernum_oneyear                  0.350918
# lasthtlordergap                   0.350918
# ordercanncelednum                 0.350918
# ordercanceledprecent              0.350918
# ctrip_profits                     0.354750
# customer_value_profit             0.363539
# delta_price2                      0.365529
# delta_price1                      0.366405
# historyvisit_avghotelnum          0.437816
# historyvisit_totalordernum        0.439774
# decisionhabit_user                0.441332
# firstorder_bu                     0.453590
# historyvisit_visit_detailpagenum  0.554698
# historyvisit_7ordernum            0.879824

# %% [markdown]
# **可视化缺失值**

# %%
import missingno as msno
msno.matrix(data)
# Out:
# <AxesSubplot: >

# %% [markdown]
# **删除缺失比例为0.879824**

# %%
data = data.drop(columns = ['historyvisit_7ordernum'])

# %% [markdown]
# ### 异常值

# %%
data.describe([0.01,0.25,0.5,0.75,0.99],include='all').T
# Out:
#                                      count unique         top    freq  \
# label                             689945.0    NaN         NaN     NaN
# sampleid                          689945.0    NaN         NaN     NaN
# d                                   689945      7  2016-05-20  111985
# arrival                             689945     37  2016-05-20  110982
# iforderpv_24h                     689945.0    NaN         NaN     NaN
# decisionhabit_user                385450.0    NaN         NaN     NaN
# historyvisit_totalordernum        386525.0    NaN         NaN     NaN
# hotelcr                           689148.0    NaN         NaN     NaN
# ordercanceledprecent              447831.0    NaN         NaN     NaN
# landhalfhours                     661312.0    NaN         NaN     NaN
# ordercanncelednum                 447831.0    NaN         NaN     NaN
# commentnums                       622029.0    NaN         NaN     NaN
# starprefer                        464892.0    NaN         NaN     NaN
# novoters                          672918.0    NaN         NaN     NaN
# consuming_capacity                463837.0    NaN         NaN     NaN
# historyvisit_avghotelnum          387876.0    NaN         NaN     NaN
# cancelrate                        678227.0    NaN         NaN     NaN
# historyvisit_visit_detailpagenum  307234.0    NaN         NaN     NaN
# delta_price1                      437146.0    NaN         NaN     NaN
# price_sensitive                   463837.0    NaN         NaN     NaN
# hoteluv                           689148.0    NaN         NaN     NaN
# businessrate_pre                  483896.0    NaN         NaN     NaN
# ordernum_oneyear                  447831.0    NaN         NaN     NaN
# cr_pre                            660548.0    NaN         NaN     NaN
# avgprice                          457261.0    NaN         NaN     NaN
# lowestprice                       687931.0    NaN         NaN     NaN
# firstorder_bu                     376993.0    NaN         NaN     NaN
# customereval_pre2                 661312.0    NaN         NaN     NaN
# delta_price2                      437750.0    NaN         NaN     NaN
# commentnums_pre                   598368.0    NaN         NaN     NaN
# customer_value_profit             439123.0    NaN         NaN     NaN
# commentnums_pre2                  648457.0    NaN         NaN     NaN
# cancelrate_pre                    653015.0    NaN         NaN     NaN
# novoters_pre2                     657616.0    NaN         NaN     NaN
# novoters_pre                      648956.0    NaN         NaN     NaN
# ctrip_profits                     445187.0    NaN         NaN     NaN
# deltaprice_pre2_t1                543180.0    NaN         NaN     NaN
# lowestprice_pre                   659689.0    NaN         NaN     NaN
# uv_pre                            660548.0    NaN         NaN     NaN
# uv_pre2                           661189.0    NaN         NaN     NaN
# lowestprice_pre2                  660664.0    NaN         NaN     NaN
# lasthtlordergap                   447831.0    NaN         NaN     NaN
# businessrate_pre2                 602960.0    NaN         NaN     NaN
# cityuvs                           682274.0    NaN         NaN     NaN
# cityorders                        651263.0    NaN         NaN     NaN
# lastpvgap                         592818.0    NaN         NaN     NaN
# cr                                457896.0    NaN         NaN     NaN
# sid                               689945.0    NaN         NaN     NaN
# visitnum_oneyear                  592910.0    NaN         NaN     NaN
# h                                 689945.0    NaN         NaN     NaN
#
#                                            mean            std      min  \
# label                                  0.274452       0.446238      0.0
# sampleid                          628540.209625  414681.498697  24636.0
# d                                           NaN            NaN      NaN
# arrival                                     NaN            NaN      NaN
# iforderpv_24h                          0.193737       0.395226      0.0
# decisionhabit_user                     5.317048      38.524483      0.0
# historyvisit_totalordernum            11.710487      17.251429      1.0
# hotelcr                                1.060996       0.045264      1.0
# ordercanceledprecent                   0.342119        0.35421      0.0
# landhalfhours                          6.086366      12.413225      0.0
# ordercanncelednum                    154.179369     398.456986      0.0
# commentnums                         1272.090888    2101.871601      0.0
# starprefer                            67.532304      19.175094      0.0
# novoters                            1706.247901    2811.690007      1.0
# consuming_capacity                     39.15414      23.240147      0.0
# historyvisit_avghotelnum               6.510179      41.045261      0.0
# cancelrate                          1051.604143    1509.066134      1.0
# historyvisit_visit_detailpagenum      37.153603      73.402891      1.0
# delta_price1                          79.067012     512.942824 -99879.0
# price_sensitive                       24.645863      26.685606      0.0
# hoteluv                               95.092708     169.981527    0.007
# businessrate_pre                       0.372717       0.232791      0.0
# ordernum_oneyear                      11.642061      17.137209      1.0
# cr_pre                                 1.062906       0.044588      1.0
# avgprice                             422.458701     290.853332      1.0
# lowestprice                          318.806242     575.782415     -3.0
# firstorder_bu                         11.697795       2.746821      1.0
# customereval_pre2                      3.048519       1.226635      0.0
# delta_price2                          77.277208     391.413839 -43344.0
# commentnums_pre                     1415.159561    2329.418922      0.0
# customer_value_profit                  3.038409       6.625281  -24.075
# commentnums_pre2                    1313.388737    1719.513354      0.0
# cancelrate_pre                         0.344422       0.179147      0.0
# novoters_pre2                       1787.197614    2316.712985      1.0
# novoters_pre                         1890.69845    3116.120062      1.0
# ctrip_profits                          4.208495       9.314438  -44.313
# deltaprice_pre2_t1                      3.28374       48.80588  -2296.0
# lowestprice_pre                      315.954583     463.723643      1.0
# uv_pre                               107.846076     186.731907    0.007
# uv_pre2                               103.35299     157.117863    0.007
# lowestprice_pre2                     318.541812     351.913035      1.0
# lasthtlordergap                     101830.9194  122784.313864      0.0
# businessrate_pre2                      0.368237       0.219945      0.0
# cityuvs                               10.648278      15.696682    0.007
# cityorders                              2.25325       3.538453    0.007
# lastpvgap                          12049.409382   25601.374138      0.0
# cr                                     1.137476       0.204789      1.0
# sid                                  153.702414     277.807697      0.0
# visitnum_oneyear                   18551.846682  228860.311117      1.0
# h                                     14.462315       6.301575      0.0
#
#                                         1%       25%       50%       75%  \
# label                                  0.0       0.0       0.0       1.0
# sampleid                          36205.88  312320.0  599637.0  887460.0
# d                                      NaN       NaN       NaN       NaN
# arrival                                NaN       NaN       NaN       NaN
# iforderpv_24h                          0.0       0.0       0.0       0.0
# decisionhabit_user                     1.0       2.0       3.0       5.0
# historyvisit_totalordernum             1.0       2.0       6.0      14.0
# hotelcr                                1.0      1.03      1.05      1.09
# ordercanceledprecent                   0.0       0.0      0.25      0.57
# landhalfhours                          0.0       0.0       0.0       4.0
# ordercanncelednum                      0.0       0.0       2.0     153.0
# commentnums                            1.0     115.0     514.0    1670.0
# starprefer                            20.0      53.3      69.4      80.3
# novoters                               1.0     157.0     692.0    2196.0
# consuming_capacity                     8.0      22.0      33.0      51.0
# historyvisit_avghotelnum               1.0       2.0       4.0       7.0
# cancelrate                             2.0     137.0     503.0    1373.0
# historyvisit_visit_detailpagenum       1.0       6.0      18.0      44.0
# delta_price1                      -1227.55     -31.0      81.0     226.0
# price_sensitive                        0.0       5.0      16.0      33.0
# hoteluv                              0.167    10.427     36.18   107.747
# businessrate_pre                      0.01      0.15      0.39      0.57
# ordernum_oneyear                       1.0       2.0       6.0      14.0
# cr_pre                                 1.0      1.03      1.06      1.09
# avgprice                              91.0     232.0     350.0     524.0
# lowestprice                           37.0     116.0     200.0     380.0
# firstorder_bu                          3.0      12.0      13.0      13.0
# customereval_pre2                      0.0       2.0       3.0       4.0
# delta_price2                        -949.0     -29.0      69.0     198.0
# commentnums_pre                        1.0     137.0     592.0    1862.0
# customer_value_profit             -0.29678     0.269     0.991     3.138
# commentnums_pre2                       3.0     270.0     768.0    1780.0
# cancelrate_pre                        0.05      0.23      0.32      0.42
# novoters_pre2                          5.0     391.0    1054.0    2413.0
# novoters_pre                           2.0     187.0     783.0    2453.0
# ctrip_profits                       -0.393      0.34     1.347      4.32
# deltaprice_pre2_t1                  -103.0      -3.0       2.0      10.0
# lowestprice_pre                       38.0     118.0     208.0     385.0
# uv_pre                                0.24    12.533      42.5   124.707
# uv_pre2                                0.5    17.563    51.287     126.2
# lowestprice_pre2                      52.0     145.0     233.0     388.0
# lasthtlordergap                      244.0   14999.0   46890.0  138953.0
# businessrate_pre2                     0.01      0.17       0.4      0.55
# cityuvs                              0.013     0.827     3.527    13.327
# cityorders                           0.007     0.127     0.627     2.747
# lastpvgap                              0.0     551.0    2848.0   10726.0
# cr                                     1.0       1.0      1.05      1.21
# sid                                    1.0      17.0      62.0     180.0
# visitnum_oneyear                      21.0     471.0    1315.0    3141.0
# h                                      0.0      11.0      15.0      20.0
#
#                                          99%        max
# label                                    1.0        1.0
# sampleid                          2226892.56  2238426.0
# d                                        NaN        NaN
# arrival                                  NaN        NaN
# iforderpv_24h                            1.0        1.0
# decisionhabit_user                      27.0     3167.0
# historyvisit_totalordernum              82.0      711.0
# hotelcr                                 1.19       3.18
# ordercanceledprecent                     1.0        1.0
# landhalfhours                           48.0       49.0
# ordercanncelednum                     1752.0    13475.0
# commentnums                           8796.0    34189.0
# starprefer                             100.0      100.0
# novoters                             11576.0    45455.0
# consuming_capacity                     100.0      100.0
# historyvisit_avghotelnum                29.0     3167.0
# cancelrate                            6399.0    18930.0
# historyvisit_visit_detailpagenum       262.0     6199.0
# delta_price1                          1081.0     5398.0
# price_sensitive                        100.0      100.0
# hoteluv                              964.113   1722.613
# businessrate_pre                         0.8       0.99
# ordernum_oneyear                        81.0      711.0
# cr_pre                                  1.19       2.95
# avgprice                              1491.0     6383.0
# lowestprice                           1823.0   100000.0
# firstorder_bu                           17.0       21.0
# customereval_pre2                        5.5        6.0
# delta_price2                          1018.0     5114.0
# commentnums_pre                       9732.0    34189.0
# customer_value_profit                 28.451    598.064
# commentnums_pre2                      7457.0    34189.0
# cancelrate_pre                           1.0        1.0
# novoters_pre2                        10018.0    45436.0
# novoters_pre                         13839.0    45436.0
# ctrip_profits                        40.7558     600.82
# deltaprice_pre2_t1                     111.0     3324.0
# lowestprice_pre                       1750.0   100000.0
# uv_pre                              1047.787   1722.613
# uv_pre2                             856.7254   1722.613
# lowestprice_pre2                      1464.0    43700.0
# lasthtlordergap                     484734.0   527026.0
# businessrate_pre2                       0.78       0.99
# cityuvs                               66.007      67.14
# cityorders                            14.453     14.507
# lastpvgap                           138722.0   194386.0
# cr                                       2.0       11.0
# sid                                   1212.0     9956.0
# visitnum_oneyear                    262567.0  9651192.0
# h                                       23.0       23.0

# %% [markdown]
# **定义盖帽法处理异常值**

# %%
data.loc[:,['lowestprice','lowestprice_pre']].describe([0.01,0.25,0.5,0.75,0.99],include='all').T
# Out:
#                     count        mean         std  min    1%    25%    50%  \
# lowestprice      687931.0  318.806242  575.782415 -3.0  37.0  116.0  200.0
# lowestprice_pre  659689.0  315.954583  463.723643  1.0  38.0  118.0  208.0
#
#                    75%     99%       max
# lowestprice      380.0  1823.0  100000.0
# lowestprice_pre  385.0  1750.0  100000.0

# %%
col_01 = ['lowestprice','lowestprice_pre'] # 偏态严重

# %%
def block_lower(x):
# x是输⼊入的Series对象,替换1%分位数
    ql = x.quantile(.01)
    out = x.mask(x<ql,ql)
    return(out)

# %%
def block_upper(x):
# x是输⼊入的Series对象,l替换99%分位数
    qu = x.quantile(.99)
    out = x.mask(x>qu,qu)
    return(out)

# %%
data.loc[:,col_01]=data.loc[:,col_01].apply(block_upper)

# %%
data.loc[:,col_01]=data.loc[:,col_01].apply(block_lower)

# %%
data.loc[:,['lowestprice','lowestprice_pre']].describe([0.01,0.25,0.5,0.75,0.99],include='all').T
# Out:
#                     count        mean         std   min    1%    25%    50%  \
# lowestprice      687931.0  305.025771  297.382838  37.0  37.0  116.0  200.0
# lowestprice_pre  659689.0  304.439507  287.192512  38.0  38.0  118.0  208.0
#
#                    75%     99%     max
# lowestprice      380.0  1823.0  1823.0
# lowestprice_pre  385.0  1750.0  1750.0

# %% [markdown]
# ## 划分测试集和训练集

# %%
data_copy = data.copy() # 备份数据

# %%
X = data_copy.iloc[:,2:]
y = data_copy.label

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,Xtest,Ytrain,Ytest = train_test_split(X,y,test_size=0.3,random_state=666)

# %%
# 特征创造

# %%
date_train = Xtrain.iloc[:,:2]
date_test = Xtest.iloc[:,:2]

# %%
date_test.reset_index(drop=True)
# Out:
#                  d     arrival
# 0       2016-05-20  2016-05-21
# 1       2016-05-15  2016-05-15
# 2       2016-05-15  2016-05-15
# 3       2016-05-20  2016-05-20
# 4       2016-05-20  2016-06-07
# ...            ...         ...
# 206979  2016-05-16  2016-05-28
# 206980  2016-05-15  2016-05-15
# 206981  2016-05-19  2016-06-09
# 206982  2016-05-19  2016-05-22
# 206983  2016-05-21  2016-05-23
#
# [206984 rows x 2 columns]

# %%
date_train.reset_index(drop=True)
# Out:
#                  d     arrival
# 0       2016-05-17  2016-05-21
# 1       2016-05-15  2016-05-15
# 2       2016-05-15  2016-05-15
# 3       2016-05-16  2016-05-16
# 4       2016-05-16  2016-05-20
# ...            ...         ...
# 482956  2016-05-17  2016-05-17
# 482957  2016-05-21  2016-06-08
# 482958  2016-05-20  2016-05-26
# 482959  2016-05-21  2016-05-21
# 482960  2016-05-18  2016-05-21
#
# [482961 rows x 2 columns]

# %%
# date_train.to_csv('date_train.csv')
# date_test.to_csv('date_test.csv') 保持特征创造数据

# %%
col_no = ['sid','iforderpv_24h','h'] #没有缺失值的特征
col_clf = ['decisionhabit_user'] # 分类型变量
col_neg = ['delta_price1','delta_price2','customer_value_profit'
           ,'ctrip_profits','deltaprice_pre2_t1'] # 含有负数
col_std = data.columns[data.describe(include='all').T['std'] >100].to_list() # std >100
col_std.remove('delta_price1')
col_std.remove('delta_price2')
col_std.remove('sampleid')
col_std.remove('lasthtlordergap')

# %%
col_35 = ['firstorder_bu','decisionhabit_user','historyvisit_totalordernum'
 ,'historyvisit_avghotelnum','customer_value_profit','ctrip_profits','ordernum_oneyear'
 ,'lasthtlordergap','ordercanceledprecent','ordercanncelednum'] # 缺失35% —— 55%

# %%
cols = X.columns.to_list()

col_norm = list(set(cols)-set(col_clf + col_std + col_neg + col_no +col_35))

# %%
col_norm
# Out:
# ['cancelrate_pre',
#  'historyvisit_visit_detailpagenum',
#  'customereval_pre2',
#  'price_sensitive',
#  'cr_pre',
#  'd',
#  'businessrate_pre2',
#  'arrival',
#  'cityorders',
#  'landhalfhours',
#  'cityuvs',
#  'businessrate_pre',
#  'hotelcr',
#  'cr',
#  'starprefer',
#  'consuming_capacity']

# %% [markdown]
# ## 缺失值填补

# %% [markdown]
# - 分类型变量用 '众数填补' —— col_clf
# - 含有负数的特征用 '中值填补' —— col_neg
# - std > 100 方差大于100的连续型变量用 '中值填补' —— col_std
# - 缺失35%——55%用 '常数 -1 填充' 单独做一类
# - 其余变量用 '均值填补' —— col_norm

# %%
Xtrain.loc[:,col_clf] = Xtrain.loc[:,col_clf].fillna(Xtrain.loc[:,col_clf].mode())

Xtrain.loc[:,col_neg] = Xtrain.loc[:,col_neg].fillna(Xtrain.loc[:,col_neg].median())

Xtrain.loc[:,col_std] = Xtrain.loc[:,col_std].fillna(Xtrain.loc[:,col_std].median())

Xtrain.loc[:,col_norm] = Xtrain.loc[:,col_norm].fillna(Xtrain.loc[:,col_norm].mean())

Xtrain.loc[:,col_35] = Xtrain.loc[:,col_35].fillna(-1)

# %%
Xtest.loc[:,col_clf] = Xtest.loc[:,col_clf].fillna(Xtest.loc[:,col_clf].mode())

# %%
Xtest.loc[:,col_neg] = Xtest.loc[:,col_neg].fillna(Xtest.loc[:,col_neg].median())

# %%
Xtest.loc[:,col_std] = Xtest.loc[:,col_std].fillna(Xtest.loc[:,col_std].median())

# %%
Xtest.loc[:,col_norm] = Xtest.loc[:,col_norm].fillna(Xtest.loc[:,col_norm].mean())

# %%
Xtest.loc[:,col_35] = Xtest.loc[:,col_35].fillna(-1)

# %% [markdown]
# **检查缺失值填补情况**

# %%
Xtrain.isna().any().sum()
# Out:
# 0

# %%
Xtest.isna().any().sum()
# Out:
# 0

# %%
# 特征创造
# ordernum_oneyear_train = Xtrain.loc[:,'ordernum_oneyear'].reset_index(drop=True)
# ordernum_oneyear_test = Xtest.loc[:,'ordernum_oneyear'].reset_index(drop=True)
# avgprice_train = Xtrain.loc[:,'avgprice'].reset_index(drop=True)
# avgprice_test = Xtest.loc[:,'avgprice'].reset_index(drop=True)

# M_train = ordernum_oneyear_train * avgprice_train

# M_test = ordernum_oneyear_test * avgprice_test

# M_train.to_csv('M_train.csv')
# M_test.to_csv('M_test.csv')
# Out:
# /Users/jim/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   if sys.path[0] == '':

# %% [markdown]
# ## 特征选择

# %%
y.value_counts()
# Out:
# 0    500588
# 1    189357
# Name: label, dtype: int64

# %%
500588/189357
# Out:
# 2.6436202516938905

# %%
y.shape
# Out:
# (647450,)

# %%
X.shape
# Out:
# (647450, 46)

# %%
Xtrain.describe().T
# Out:
#                                      count          mean            std  \
# iforderpv_24h                     453215.0      0.201838       0.401372
# decisionhabit_user                453215.0      2.546994      28.826308
# historyvisit_totalordernum        453215.0      6.202946      14.451892
# hotelcr                           453215.0      1.061454       0.043997
# ordercanceledprecent              453215.0     -0.125021       0.700082
# landhalfhours                     453215.0      6.098000      12.426783
# ordercanncelednum                 453215.0    101.666377     330.494971
# commentnums                       453215.0   1212.599168    2008.781232
# starprefer                        453215.0     67.554105      15.730849
# novoters                          453215.0   1702.318985    2782.367547
# consuming_capacity                453215.0     39.125564      19.032548
# historyvisit_avghotelnum          453215.0      3.246288      31.140310
# cancelrate                        453215.0   1054.940348    1497.755834
# historyvisit_visit_detailpagenum  453215.0     37.277657      48.113075
# delta_price1                      453215.0     79.637132     380.142957
# price_sensitive                   453215.0     24.610911      21.887052
# hoteluv                           453215.0     95.386331     168.740935
# businessrate_pre                  453215.0      0.374607       0.199691
# ordernum_oneyear                  453215.0      7.278256      15.133819
# cr_pre                            453215.0      1.063273       0.044274
# avgprice                          453215.0    397.698011     239.570678
# lowestprice                       453215.0    304.873833     293.741115
# firstorder_bu                     453215.0      5.961391       6.639070
# customereval_pre2                 453215.0      3.068776       1.221252
# delta_price2                      453215.0     74.450014     310.213887
# commentnums_pre                   453215.0   1357.397401    2258.988332
# customer_value_profit             453215.0      2.304670       5.407027
# commentnums_pre2                  453215.0   1320.779800    1719.902627
# cancelrate_pre                    453215.0      0.342656       0.175678
# novoters_pre2                     453215.0   1807.292173    2331.202376
# novoters_pre                      453215.0   1898.763031    3132.148117
# ctrip_profits                     453215.0      3.202696       7.585511
# deltaprice_pre2_t1                453215.0      3.107766      44.106945
# lowestprice_pre                   453215.0    307.776563     287.287507
# uv_pre                            453215.0    108.736388     187.057558
# uv_pre2                           453215.0    104.285620     157.168167
# lowestprice_pre2                  453215.0    321.682537     340.025867
# lasthtlordergap                   453215.0  66203.311153  110179.166368
# businessrate_pre2                 453215.0      0.370167       0.210135
# cityuvs                           453215.0     10.850555      15.741808
# cityorders                        453215.0      2.287862       3.471345
# lastpvgap                         453215.0  10808.350968   24023.659231
# cr                                453215.0      1.139221       0.168966
# sid                               453215.0    154.290990     277.540359
# visitnum_oneyear                  453215.0  13461.044416  190199.207950
# h                                 453215.0     14.466401       6.306481
#
#                                         min      25%           50%  \
# iforderpv_24h                         0.000    0.000      0.000000
# decisionhabit_user                   -1.000   -1.000      1.000000
# historyvisit_totalordernum           -1.000   -1.000      1.000000
# hotelcr                               1.000    1.030      1.050000
# ordercanceledprecent                 -1.000   -1.000      0.000000
# landhalfhours                         0.000    0.000      0.000000
# ordercanncelednum                     0.000    1.000      2.000000
# commentnums                           0.000  149.000    530.000000
# starprefer                            0.000   60.000     67.554105
# novoters                              1.000  173.000    714.000000
# consuming_capacity                    0.000   27.000     39.125564
# historyvisit_avghotelnum             -1.000   -1.000      1.000000
# cancelrate                            1.000  147.000    516.000000
# historyvisit_visit_detailpagenum      1.000   23.000     37.277657
# delta_price1                     -43353.000   30.000     81.000000
# price_sensitive                       0.000   10.000     24.610911
# hoteluv                               0.007   10.967     36.933000
# businessrate_pre                      0.000    0.250      0.374607
# ordernum_oneyear                     -1.000   -1.000      2.000000
# cr_pre                                1.000    1.030      1.060000
# avgprice                              1.000  290.000    349.000000
# lowestprice                          37.000  118.000    203.000000
# firstorder_bu                        -1.000   -1.000      7.000000
# customereval_pre2                     0.000    2.000      3.000000
# delta_price2                     -34772.000   25.000     69.000000
# commentnums_pre                       0.000  173.000    606.000000
# customer_value_profit               -24.075    0.594      0.995000
# commentnums_pre2                      0.000  287.000    784.000000
# cancelrate_pre                        0.000    0.230      0.320000
# novoters_pre2                         1.000  407.000   1075.000000
# novoters_pre                          1.000  202.000    803.000000
# ctrip_profits                       -44.313    0.767      1.353000
# deltaprice_pre2_t1                -2296.000   -1.000      2.000000
# lowestprice_pre                      38.000  119.000    210.000000
# uv_pre                                0.007   13.013     43.413000
# uv_pre2                               0.007   18.071     52.291000
# lowestprice_pre2                     21.000  147.000    236.000000
# lasthtlordergap                      -1.000   -1.000  13424.000000
# businessrate_pre2                     0.000    0.200      0.370167
# cityuvs                               0.007    0.893      3.740000
# cityorders                            0.007    0.140      0.767000
# lastpvgap                             0.000  727.000   2858.000000
# cr                                    1.000    1.000      1.139221
# sid                                   0.000   17.000     63.000000
# visitnum_oneyear                      1.000  575.000   1306.000000
# h                                     0.000   11.000     15.000000
#
#                                            75%          max
# iforderpv_24h                         0.000000        1.000
# decisionhabit_user                    3.000000     2383.000
# historyvisit_totalordernum            7.000000      711.000
# hotelcr                               1.090000        2.950
# ordercanceledprecent                  0.400000        1.000
# landhalfhours                         4.000000       49.000
# ordercanncelednum                     5.000000    13475.000
# commentnums                        1507.000000    34189.000
# starprefer                           77.100000      100.000
# novoters                           2172.000000    45455.000
# consuming_capacity                   41.000000      100.000
# historyvisit_avghotelnum              4.400000     2666.700
# cancelrate                         1376.000000    18930.000
# historyvisit_visit_detailpagenum     37.277657     6199.000
# delta_price1                        140.000000     5398.000
# price_sensitive                      24.610911      100.000
# hoteluv                             108.800000     1722.613
# businessrate_pre                      0.510000        0.990
# ordernum_oneyear                      9.000000      711.000
# cr_pre                                1.090000        2.950
# avgprice                            422.000000     6383.000
# lowestprice                         379.000000     1823.000
# firstorder_bu                        13.000000       21.000
# customereval_pre2                     4.000000        6.000
# delta_price2                        122.000000     5114.000
# commentnums_pre                    1688.000000    34189.000
# customer_value_profit                 1.623000      598.064
# commentnums_pre2                   1777.000000    34189.000
# cancelrate_pre                        0.420000        1.000
# novoters_pre2                      2435.000000    45436.000
# novoters_pre                       2438.000000    45436.000
# ctrip_profits                         2.287000      600.820
# deltaprice_pre2_t1                    8.000000     2600.000
# lowestprice_pre                     388.000000     1750.000
# uv_pre                              126.133000     1722.613
# uv_pre2                             127.733000     1722.613
# lowestprice_pre2                    390.000000    35800.000
# lasthtlordergap                   78013.500000   527026.000
# businessrate_pre2                     0.540000        0.990
# cityuvs                              13.387000       67.140
# cityorders                            2.667000       14.507
# lastpvgap                          8078.000000   194386.000
# cr                                    1.139221       11.000
# sid                                 181.000000     9956.000
# visitnum_oneyear                   2657.000000  9651192.000
# h                                    20.000000       23.000

# %% [markdown]
# ### 方差过滤

# %%
from sklearn.feature_selection import VarianceThreshold
selector = VarianceThreshold()
Xtrain_var0 = selector.fit(Xtrain).transform(Xtrain)

# %%
Xtrain.shape
# Out:
# (453215, 46)

# %%
Xtrain_var0.shape
# Out:
# (453215, 46)

# %% [markdown]
# ### F_检验

# %%
from sklearn.feature_selection import f_classif
F , pvalues_f = f_classif(Xtrain,Ytrain)

# %%
F
# Out:
# array([5.18088618e+03, 5.12914839e-01, 1.02619051e+04, 6.37370167e+03,
#        5.30010765e+03, 2.70217161e+02, 4.34537318e+03, 4.84511347e-01,
#        1.16181496e+01, 3.52392149e+00, 2.13195698e+02, 3.07708319e+00,
#        4.70206035e+01, 3.78887065e-03, 6.02023694e+02, 2.67662297e+00,
#        1.21350512e+03, 6.16452744e+03, 1.15690189e+04, 6.11494229e+03,
#        8.27244190e+01, 1.77123331e+03, 8.18078891e+02, 3.95113044e+02,
#        9.85716294e+02, 5.25057169e+01, 2.82920103e+03, 9.78747840e+01,
#        1.67864913e+02, 4.39022169e+01, 2.19709627e+01, 2.68753256e+03,
#        8.89432174e+00, 1.81610831e+03, 1.80269439e+03, 2.26639969e+03,
#        2.01498626e+03, 4.00817309e+02, 8.08901019e+03, 4.47914514e+03,
#        4.29633150e+03, 4.94223819e+01, 1.45569434e+04, 6.40401277e+01,
#        2.16315278e+02, 2.80263803e+03])

# %%
pvalues_f
# Out:
# array([0.00000000e+000, 4.73880129e-001, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 1.05972860e-060, 0.00000000e+000, 4.86386294e-001,
#        6.53170237e-004, 6.04898094e-002, 2.82921998e-048, 7.94034836e-002,
#        7.03336998e-012, 9.50918194e-001, 7.42451145e-133, 1.01832161e-001,
#        1.59590431e-265, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        9.46940113e-020, 0.00000000e+000, 9.16150906e-180, 6.95578987e-088,
#        3.90800284e-216, 4.29675225e-013, 0.00000000e+000, 4.48102482e-023,
#        2.19956440e-038, 3.45581424e-011, 2.76887169e-006, 0.00000000e+000,
#        2.86074056e-003, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 3.99644007e-089, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 2.06666985e-012, 0.00000000e+000, 1.22195308e-015,
#        5.90820099e-049, 0.00000000e+000])

# %% [markdown]
# **与标签没有显著相关性的变量有6个**

# %%
(pvalues_f>0.01).sum()
# Out:
# 6

# %% [markdown]
# **剔除没有相关性的变量**

# %%
col_f = list(Xtrain.columns[pvalues_f<0.01])
col_f
# Out:
# ['iforderpv_24h',
#  'historyvisit_totalordernum',
#  'hotelcr',
#  'ordercanceledprecent',
#  'landhalfhours',
#  'ordercanncelednum',
#  'starprefer',
#  'consuming_capacity',
#  'cancelrate',
#  'delta_price1',
#  'hoteluv',
#  'businessrate_pre',
#  'ordernum_oneyear',
#  'cr_pre',
#  'avgprice',
#  'lowestprice',
#  'firstorder_bu',
#  'customereval_pre2',
#  'delta_price2',
#  'commentnums_pre',
#  'customer_value_profit',
#  'commentnums_pre2',
#  'cancelrate_pre',
#  'novoters_pre2',
#  'novoters_pre',
#  'ctrip_profits',
#  'deltaprice_pre2_t1',
#  'lowestprice_pre',
#  'uv_pre',
#  'uv_pre2',
#  'lowestprice_pre2',
#  'lasthtlordergap',
#  'businessrate_pre2',
#  'cityuvs',
#  'cityorders',
#  'lastpvgap',
#  'cr',
#  'sid',
#  'visitnum_oneyear',
#  'h']

# %%
Xtrain = Xtrain.loc[:,col_f]

# %%
Xtest = Xtest.loc[:,col_f]

# %%
Xtrain.index = range(Xtrain.shape[0]) # 重置索引
Xtrain
# Out:
#         iforderpv_24h  historyvisit_totalordernum  hotelcr  \
# 0                   0                        -1.0     1.01
# 1                   0                        -1.0     1.06
# 2                   0                        16.0     1.04
# 3                   0                         1.0     1.01
# 4                   1                         8.0     1.13
# ...               ...                         ...      ...
# 453210              0                        -1.0     1.03
# 453211              0                        74.0     1.01
# 453212              1                        -1.0     1.08
# 453213              0                         2.0     1.00
# 453214              0                         3.0     1.06
#
#         ordercanceledprecent  landhalfhours  ordercanncelednum  starprefer  \
# 0                      -1.00            0.0                2.0   67.554105
# 1                       0.19            3.0               63.0   82.400000
# 2                       0.43           30.0              571.0   96.400000
# 3                       0.00            0.0                0.0   68.000000
# 4                       0.98            0.0              293.0   56.400000
# ...                      ...            ...                ...         ...
# 453210                  0.01            2.0                1.0   30.000000
# 453211                  0.55            7.0             2367.0   57.900000
# 453212                 -1.00           38.0                2.0   67.554105
# 453213                  0.00            0.0                0.0   40.000000
# 453214                  0.67            0.0                2.0   64.000000
#
#         consuming_capacity  cancelrate  delta_price1  ...  lowestprice_pre2  \
# 0                39.125564        89.0          81.0  ...             172.0
# 1                72.000000      3978.0         107.0  ...             354.0
# 2                69.000000      3428.0          37.0  ...             395.0
# 3                31.000000       321.0        -144.0  ...             530.0
# 4                25.000000       689.0          72.0  ...             185.0
# ...                    ...         ...           ...  ...               ...
# 453210           21.000000      2111.0         -55.0  ...             236.0
# 453211           31.000000        11.0         137.0  ...             203.0
# 453212           39.125564      1789.0          81.0  ...             306.0
# 453213           22.000000         2.0          41.0  ...             223.0
# 453214           25.000000      1949.0         121.0  ...             160.0
#
#         lasthtlordergap  businessrate_pre2  cityuvs  cityorders  lastpvgap  \
# 0                  -1.0           0.050000    2.267       0.133        0.0
# 1               23823.0           0.550000   25.080       3.353     1753.0
# 2               30793.0           0.230000   10.747       1.613    30792.0
# 3              355113.0           0.300000    0.913       0.140      806.0
# 4              161858.0           0.810000    0.107       0.007    19664.0
# ...                 ...                ...      ...         ...        ...
# 453210         135349.0           0.120000    1.747       0.107     1182.0
# 453211           3243.0           0.650000   11.073       2.147     1509.0
# 453212             -1.0           0.390000    8.547       1.400     2858.0
# 453213         120184.0           0.370167   20.513       4.347    27707.0
# 453214         167434.0           0.360000    0.507       0.053       35.0
#
#               cr  sid  visitnum_oneyear   h
# 0       1.139221   27            1050.0   0
# 1       1.139221  257            5780.0  14
# 2       1.200000  205            3616.0  11
# 3       1.000000  184            1064.0  13
# 4       1.000000  286            1468.0  14
# ...          ...  ...               ...  ..
# 453210  1.139221  128           13213.0   2
# 453211  1.380000  727            8826.0  20
# 453212  1.139221    1            1306.0  20
# 453213  2.000000    5            1295.0   0
# 453214  1.000000   70            1422.0  19
#
# [453215 rows x 40 columns]

# %%
Ytrain = Ytrain.reset_index(drop=True)

# %%
Xtest.index = range(Xtest.shape[0]) # 重置索引
Xtest.head()
# Out:
#    iforderpv_24h  historyvisit_totalordernum  hotelcr  ordercanceledprecent  \
# 0              1                         5.0     1.07                  0.60
# 1              0                        -1.0     1.08                 -1.00
# 2              0                         1.0     1.02                  0.00
# 3              0                         2.0     1.11                  0.00
# 4              0                        28.0     1.12                  0.29
#
#    landhalfhours  ordercanncelednum  starprefer  consuming_capacity  \
# 0           46.0                3.0   40.000000            9.000000
# 1           39.0                2.0   67.541185           39.083482
# 2            9.0                0.0   40.000000           16.000000
# 3            0.0                0.0   80.000000           51.000000
# 4            0.0              107.0   88.800000           51.000000
#
#    cancelrate  delta_price1  ...  lowestprice_pre2  lasthtlordergap  \
# 0      3415.0        -308.0  ...             501.0           1116.0
# 1       376.0          79.0  ...             120.0             -1.0
# 2       479.0          40.0  ...             247.0         198614.0
# 3       378.0         284.0  ...             152.0          16440.0
# 4      1422.0         588.0  ...             222.0           5079.0
#
#    businessrate_pre2  cityuvs  cityorders  lastpvgap        cr  sid  \
# 0               0.50   56.487      12.653       19.0  1.020000  814
# 1               0.56    2.567       0.280     2862.0  1.138505    2
# 2               0.47   21.747       3.133     8856.0  1.000000   73
# 3               0.54   17.933       4.913      222.0  1.250000   33
# 4               0.33    0.213       0.020     1869.0  1.190000   85
#
#    visitnum_oneyear   h
# 0            6408.0   5
# 1            1292.0  11
# 2             345.0  23
# 3             325.0  15
# 4            9218.0  16
#
# [5 rows x 40 columns]

# %%
Ytest = Ytest.reset_index(drop=True)

# %% [markdown]
# ### 嵌入法筛选特征

# %%
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import cross_val_score

# %%
# 初步探索
RFC_clf = RFC(n_estimators=10,random_state=0)
X_embedded = SelectFromModel(RFC_clf,threshold=0.05).fit_transform(Xtrain,Ytrain)
# Out:
# /Users/jim/opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_selection/_base.py:81: UserWarning: No features were selected: either the data is too noisy or the selection test too strict.
#   UserWarning)

# %% [markdown]
# **利用随机森林调出特征重要性**

# %%
importance = RFC_clf.fit(Xtrain,Ytrain).feature_importances_

# %%
Xtrain.shape
# Out:
# (453215, 40)

# %%
Ytrain.shape
# Out:
# (453215,)

# %%
from time import time
import datetime # 计时器

# %%
importance = RFC_clf.fit(Xtrain,Ytrain).feature_importances_
threshold = np.linspace(0,importance.max(),20)
X_embedded = SelectFromModel(RFC_clf,threshold=i).fit_transform(Xtrain,Ytrain)
val = cross_val_score(RFC_clf,X_embedded,Ytrain,cv=5).mean()

# %% [markdown]
# **嵌入法画学习曲线**

# %%
importance = RFC_clf.fit(Xtrain,Ytrain).feature_importances_
threshold = np.linspace(0,importance.max(),20)
score = []
time0 = time()
for i in threshold:
    X_embedded = SelectFromModel(RFC_clf,threshold=i).fit_transform(Xtrain,Ytrain)
    val = cross_val_score(RFC_clf,X_embedded,Ytrain,cv=5).mean()
    score.append(val)
print(datetime.datetime.fromtimestamp(time()-time0).strftime("%M:%S:%f"))
plt.plot(threshold,score)
plt.show();
# Out:
# 29:13:599354

# %%
np.max(score) #最高分
# Out:
# 0.9453085180322806

# %%
threshold[np.argmax(score)] #最高分对应的重要性阈值
# Out:
# 0.029595611302335584

# %%
X_embedded = SelectFromModel(RFC_clf,threshold=0.029595611302335584).fit_transform(Xtrain,Ytrain)

# %%
col_k = list(Xtrain.columns[RFC_clf.feature_importances_>0.029595611302335584])

# %% [markdown]
# **利用阈值选择出 8 个特征**

# %%
col_k_ = ['lasthtlordergap',
 'cityorders',
 'lastpvgap',
 'cr',
 'sid',
 'visitnum_oneyear',
 'h']

# %%
col_k
# Out:
# ['lasthtlordergap',
#  'cityuvs',
#  'cityorders',
#  'lastpvgap',
#  'cr',
#  'sid',
#  'visitnum_oneyear',
#  'h']

# %%
Xtrain_new = pd.DataFrame(X_embedded,columns = col_k )
Xtrain_new.head()
# Out:
#    lasthtlordergap  cityuvs  cityorders  lastpvgap        cr    sid  \
# 0             -1.0    2.267       0.133        0.0  1.139221   27.0
# 1          23823.0   25.080       3.353     1753.0  1.139221  257.0
# 2          30793.0   10.747       1.613    30792.0  1.200000  205.0
# 3         355113.0    0.913       0.140      806.0  1.000000  184.0
# 4         161858.0    0.107       0.007    19664.0  1.000000  286.0
#
#    visitnum_oneyear     h
# 0            1050.0   0.0
# 1            5780.0  14.0
# 2            3616.0  11.0
# 3            1064.0  13.0
# 4            1468.0  14.0

# %%
Xtest.loc[:,col_k_].reset_index(drop=True).head()
# Out:
#    lasthtlordergap  cityorders  lastpvgap        cr  sid  visitnum_oneyear   h
# 0           1116.0      12.653       19.0  1.020000  814            6408.0   5
# 1             -1.0       0.280     2862.0  1.138505    2            1292.0  11
# 2         198614.0       3.133     8856.0  1.000000   73             345.0  23
# 3          16440.0       4.913      222.0  1.250000   33             325.0  15
# 4           5079.0       0.020     1869.0  1.190000   85            9218.0  16

# %% [markdown]
# **保存清洗后的数据**

# %%
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(Xtrain_new.corr(),annot=True,linewidths=1)

# %% [markdown]
# 发现cityorders 与 cityuvs 高度相关

# %%
Xtrain_new.drop(columns='cityuvs',axis=1,inplace=True)
Xtest_new.drop(columns='cityuvs',axis=1,inplace=True)

# %%
Xtrain_new.to_csv('Xtrain_new.csv')
Xtest_new.to_csv('Xtest_new.csv')
Ytrain.to_csv('Ytrain.csv')
Ytest.to_csv('Ytest.csv')
# Out:
# /Users/jim/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/jim/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   after removing the cwd from sys.path.
