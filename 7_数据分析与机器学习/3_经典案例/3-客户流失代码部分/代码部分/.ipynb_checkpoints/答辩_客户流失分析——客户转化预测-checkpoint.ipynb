# %% [markdown]
# 作者：云朵君
# 公众号：数据STUDIO
# 代码仓促整理，若有问题，请及时联系云朵君

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['font.family'] = ['Arial Unicode MS']#显示中文,解决图中无法显示中文的问题
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# # 数据清洗

# %% [markdown]
# ## 导入数据

# %%
data = pd.read_table('userlostprob.txt')
data.head()
# Out:
#    label  sampleid           d     arrival  iforderpv_24h  decisionhabit_user  \
# 0      0     24636  2016-05-18  2016-05-18              0                 NaN
# 1      1     24637  2016-05-18  2016-05-18              0                 NaN
# 2      0     24641  2016-05-18  2016-05-19              0                 NaN
# 3      0     24642  2016-05-18  2016-05-18              0                 NaN
# 4      1     24644  2016-05-18  2016-05-19              0                 NaN
#
#    historyvisit_7ordernum  historyvisit_totalordernum  hotelcr  \
# 0                     NaN                         NaN     1.04
# 1                     NaN                         NaN     1.06
# 2                     NaN                         NaN     1.05
# 3                     NaN                         NaN     1.01
# 4                     NaN                         NaN     1.00
#
#    ordercanceledprecent  ...  lowestprice_pre2  lasthtlordergap  \
# 0                   NaN  ...             615.0              NaN
# 1                   NaN  ...             513.0              NaN
# 2                   NaN  ...             382.0              NaN
# 3                   NaN  ...             203.0              NaN
# 4                   NaN  ...              84.0              NaN
#
#    businessrate_pre2  cityuvs  cityorders  lastpvgap  cr  sid  \
# 0               0.29   12.880       3.147        NaN NaN    7
# 1               0.53   17.933       4.913        NaN NaN   33
# 2               0.60    3.993       0.760        NaN NaN   10
# 3               0.18    3.220       0.660        NaN NaN    8
# 4                NaN    0.013         NaN        NaN NaN    1
#
#    visitnum_oneyear   h
# 0               NaN  12
# 1               NaN  14
# 2               NaN  19
# 3               NaN  16
# 4               NaN  21
#
# [5 rows x 51 columns]

# %% [markdown]
# ## 数据探索分析

# %%
data.shape
# Out:
# (689945, 51)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689945 entries, 0 to 689944
# Data columns (total 51 columns):
# label                               689945 non-null int64
# sampleid                            689945 non-null int64
# d                                   689945 non-null object
# arrival                             689945 non-null object
# iforderpv_24h                       689945 non-null int64
# decisionhabit_user                  385450 non-null float64
# historyvisit_7ordernum              82915 non-null float64
# historyvisit_totalordernum          386525 non-null float64
# hotelcr                             689148 non-null float64
# ordercanceledprecent                447831 non-null float64
# landhalfhours                       661312 non-null float64
# ordercanncelednum                   447831 non-null float64
# commentnums                         622029 non-null float64
# starprefer                          464892 non-null float64
# novoters                            672918 non-null float64
# consuming_capacity                  463837 non-null float64
# historyvisit_avghotelnum            387876 non-null float64
# cancelrate                          678227 non-null float64
# historyvisit_visit_detailpagenum    307234 non-null float64
# delta_price1                        437146 non-null float64
# price_sensitive                     463837 non-null float64
# hoteluv                             689148 non-null float64
# businessrate_pre                    483896 non-null float64
# ordernum_oneyear                    447831 non-null float64
# cr_pre                              660548 non-null float64
# avgprice                            457261 non-null float64
# lowestprice                         687931 non-null float64
# firstorder_bu                       376993 non-null float64
# customereval_pre2                   661312 non-null float64
# delta_price2                        437750 non-null float64
# commentnums_pre                     598368 non-null float64
# customer_value_profit               439123 non-null float64
# commentnums_pre2                    648457 non-null float64
# cancelrate_pre                      653015 non-null float64
# novoters_pre2                       657616 non-null float64
# novoters_pre                        648956 non-null float64
# ctrip_profits                       445187 non-null float64
# deltaprice_pre2_t1                  543180 non-null float64
# lowestprice_pre                     659689 non-null float64
# uv_pre                              660548 non-null float64
# uv_pre2                             661189 non-null float64
# lowestprice_pre2                    660664 non-null float64
# lasthtlordergap                     447831 non-null float64
# businessrate_pre2                   602960 non-null float64
# cityuvs                             682274 non-null float64
# cityorders                          651263 non-null float64
# lastpvgap                           592818 non-null float64
# cr                                  457896 non-null float64
# sid                                 689945 non-null int64
# visitnum_oneyear                    592910 non-null float64
# h                                   689945 non-null int64
# dtypes: float64(44), int64(5), object(2)
# memory usage: 268.5+ MB

# %% [markdown]
# | 字段                             | 解释                                      |
# | -------------------------------- | ----------------------------------------- |
# | sampleid                         | 样本id                                    |
# | label                            | 目标变量                                  |
# | d                                | 访问日期                                  |
# | arrival                          | 入住日期                                  |
# | iforderpv_24h                    | 24小时内是否访问订单填写页                |
# | decisionhabit_user               | 决策习惯：以用户为单位观察决策习惯        |
# | historyvisit_7ordernum           | 近7天用户历史订单数                       |
# | historyvisit_totalordernum       | 近1年用户历史订单数                       |
# | hotelcr                          | 当前酒店历史cr                            |
# | ordercanceledprecent             | 用户一年内取消订单率                      |
# | landhalfhours                    | 24小时内登陆时长                          |
# | ordercanncelednum                | 用户一年内取消订单数                      |
# | commentnums                      | 当前酒店点评数                            |
# | starprefer                       | 星级偏好                                  |
# | novoters                         | 当前酒店评分人数                          |
# | consuming_capacity               | 消费能力指数                              |
# | historyvisit_avghotelnum         | 近3个月用户历史日均访问酒店数             |
# | cancelrate                       | 当前酒店历史取消率                        |
# | historyvisit_visit_detailpagenum | 7天内访问酒店详情页数                     |
# | delta_price1                     | 用户偏好价格-24小时浏览最多酒店价格       |
# | price_sensitive                  | 价格敏感指数                              |
# | hoteluv                          | 当前酒店历史uv                            |
# | businessrate_pre                 | 24小时历史浏览次数最多酒店商务属性指数    |
# | ordernum_oneyear                 | 用户年订单数                              |
# | cr_pre                           | 24小时历史浏览次数最多酒店历史cr          |
# | avgprice                         | 平均价格                                  |
# | lowestprice                      | 当前酒店可定最低价                        |
# | firstorder_bu                    | 首单bu                                    |
# | customereval_pre2                | 24小时历史浏览酒店客户评分均值            |
# | delta_price2                     | 用户偏好价格-24小时浏览酒店平均价格       |
# | commentnums_pre                  | 24小时历史浏览次数最多酒店点评数          |
# | customer_value_profit            | 客户价值_近1年                            |
# | commentnums_pre2                 | 24小时历史浏览酒店点评数均值              |
# | cancelrate_pre                   | 24小时内已访问次数最多酒店历史取消率      |
# | novoters_pre2                    | 24小时历史浏览酒店评分人数均值            |
# | novoters_pre                     | 24小时历史浏览次数最多酒店评分人数        |
# | ctrip_profits                    | 客户价值                                  |
# | deltaprice_pre2_t1               | 24小时内已访问酒店价格与对手价差均值，t+1 |
# | lowestprice_pre                  | 24小时内已访问次数最多酒店可订最低价      |
# | uv_pre                           | 24小时历史浏览次数最多酒店历史uv          |
# | uv_pre2                          | 24小时历史浏览酒店历史uv均值              |
# | lowestprice_pre2                 | 24小时内已访问酒店可订最低价均值          |
# | lasthtlordergap                  | 一年内距离上次下单时长                    |
# | businessrate_pre2                | 24小时内已访问酒店商务属性指数均值        |
# | cityuvs                          | 昨日访问当前城市同入住日期的app  uv数     |
# | cityorders                       | 昨日提交当前城市同入住日期的app订单数     |
# | lastpvgap                        | 一年内距上次访问时长                      |
# | cr                               | 用户转化率                                |
# | sid                              | 会话id，sid=1可认为是新访                 |
# | visitnum_oneyear                 | 年访问次数                                |
# | h                                | 访问时间点                                |

# %% [markdown]
# ### 重复值

# %%
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (689945, 51)

# %% [markdown]
# ### 缺失值

# %% [markdown]
# **查看缺失值比例，并排序**

# %%
null_ = data.isna().mean().reset_index().sort_values(by=0)

null_1 = null_.rename(columns={'index':'特征',0:'缺失比'}).reset_index(drop=True)

# %%
null_1
# Out:
#                                   特征       缺失比
# 0                              label  0.000000
# 1                                sid  0.000000
# 2                      iforderpv_24h  0.000000
# 3                                  h  0.000000
# 4                                  d  0.000000
# 5                           sampleid  0.000000
# 6                            arrival  0.000000
# 7                            hotelcr  0.001155
# 8                            hoteluv  0.001155
# 9                        lowestprice  0.002919
# 10                           cityuvs  0.011118
# 11                        cancelrate  0.016984
# 12                          novoters  0.024679
# 13                 customereval_pre2  0.041500
# 14                     landhalfhours  0.041500
# 15                           uv_pre2  0.041679
# 16                  lowestprice_pre2  0.042440
# 17                            uv_pre  0.042608
# 18                            cr_pre  0.042608
# 19                   lowestprice_pre  0.043853
# 20                     novoters_pre2  0.046857
# 21                    cancelrate_pre  0.053526
# 22                        cityorders  0.056065
# 23                      novoters_pre  0.059409
# 24                  commentnums_pre2  0.060132
# 25                       commentnums  0.098437
# 26                 businessrate_pre2  0.126075
# 27                   commentnums_pre  0.132731
# 28                  visitnum_oneyear  0.140642
# 29                         lastpvgap  0.140775
# 30                deltaprice_pre2_t1  0.212720
# 31                  businessrate_pre  0.298646
# 32                        starprefer  0.326190
# 33                   price_sensitive  0.327719
# 34                consuming_capacity  0.327719
# 35                                cr  0.336330
# 36                          avgprice  0.337250
# 37                  ordernum_oneyear  0.350918
# 38                   lasthtlordergap  0.350918
# 39                 ordercanncelednum  0.350918
# 40              ordercanceledprecent  0.350918
# 41                     ctrip_profits  0.354750
# 42             customer_value_profit  0.363539
# 43                      delta_price2  0.365529
# 44                      delta_price1  0.366405
# 45          historyvisit_avghotelnum  0.437816
# 46        historyvisit_totalordernum  0.439774
# 47                decisionhabit_user  0.441332
# 48                     firstorder_bu  0.453590
# 49  historyvisit_visit_detailpagenum  0.554698
# 50            historyvisit_7ordernum  0.879824

# %%
import seaborn as sns

# %%
plt.figure(figsize=(8,6))
sns.kdeplot(null_1['缺失比'],shade=True)
# Out:
# findfont: Font family ['Arial Unicode MS'] not found. Falling back to DejaVu Sans.
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32570 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22833 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27604 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32570 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22833 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27604 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.figure(figsize=(8,6))
plt.barh(range(null_1.shape[0]),null_1['缺失比'],label='缺失比')
plt.legend(loc=4)
plt.ylabel('特征变量',fontsize=15);
# Out:
# findfont: Font family ['Arial Unicode MS'] not found. Falling back to DejaVu Sans.
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 29305 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24449 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 37327 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 29305 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24449 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21464 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 37327 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
null_.rename(columns={'index':'特征',0:'缺失比'}).set_index('特征')
# Out:
#                                        缺失比
# 特征
# label                             0.000000
# sid                               0.000000
# iforderpv_24h                     0.000000
# h                                 0.000000
# d                                 0.000000
# sampleid                          0.000000
# arrival                           0.000000
# hotelcr                           0.001155
# hoteluv                           0.001155
# lowestprice                       0.002919
# cityuvs                           0.011118
# cancelrate                        0.016984
# novoters                          0.024679
# customereval_pre2                 0.041500
# landhalfhours                     0.041500
# uv_pre2                           0.041679
# lowestprice_pre2                  0.042440
# uv_pre                            0.042608
# cr_pre                            0.042608
# lowestprice_pre                   0.043853
# novoters_pre2                     0.046857
# cancelrate_pre                    0.053526
# cityorders                        0.056065
# novoters_pre                      0.059409
# commentnums_pre2                  0.060132
# commentnums                       0.098437
# businessrate_pre2                 0.126075
# commentnums_pre                   0.132731
# visitnum_oneyear                  0.140642
# lastpvgap                         0.140775
# deltaprice_pre2_t1                0.212720
# businessrate_pre                  0.298646
# starprefer                        0.326190
# price_sensitive                   0.327719
# consuming_capacity                0.327719
# cr                                0.336330
# avgprice                          0.337250
# ordernum_oneyear                  0.350918
# lasthtlordergap                   0.350918
# ordercanncelednum                 0.350918
# ordercanceledprecent              0.350918
# ctrip_profits                     0.354750
# customer_value_profit             0.363539
# delta_price2                      0.365529
# delta_price1                      0.366405
# historyvisit_avghotelnum          0.437816
# historyvisit_totalordernum        0.439774
# decisionhabit_user                0.441332
# firstorder_bu                     0.453590
# historyvisit_visit_detailpagenum  0.554698
# historyvisit_7ordernum            0.879824

# %% [markdown]
# **可视化缺失值**

# %%
import missingno as msno
msno.matrix(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-e1455c75c420> in <module>
# ----> 1 import missingno as msno
#       2 msno.matrix(data)
#
# ModuleNotFoundError: No module named 'missingno'

# %% [markdown]
# **删除缺失比例为0.879824**

# %%
data = data.drop(columns = ['historyvisit_7ordernum'])

# %% [markdown]
# ### 异常值

# %%
data.describe([0.01,0.25,0.5,0.75,0.99],include='all').T
# Out:
#                                    count unique         top    freq      mean  \
# label                             689945    NaN         NaN     NaN  0.274452
# sampleid                          689945    NaN         NaN     NaN    628540
# d                                 689945      7  2016-05-20  111985       NaN
# arrival                           689945     37  2016-05-20  110982       NaN
# iforderpv_24h                     689945    NaN         NaN     NaN  0.193737
# decisionhabit_user                385450    NaN         NaN     NaN   5.31705
# historyvisit_7ordernum             82915    NaN         NaN     NaN   1.85609
# historyvisit_totalordernum        386525    NaN         NaN     NaN   11.7105
# hotelcr                           689148    NaN         NaN     NaN     1.061
# ordercanceledprecent              447831    NaN         NaN     NaN  0.342119
# landhalfhours                     661312    NaN         NaN     NaN   6.08637
# ordercanncelednum                 447831    NaN         NaN     NaN   154.179
# commentnums                       622029    NaN         NaN     NaN   1272.09
# starprefer                        464892    NaN         NaN     NaN   67.5323
# novoters                          672918    NaN         NaN     NaN   1706.25
# consuming_capacity                463837    NaN         NaN     NaN   39.1541
# historyvisit_avghotelnum          387876    NaN         NaN     NaN   6.51018
# cancelrate                        678227    NaN         NaN     NaN    1051.6
# historyvisit_visit_detailpagenum  307234    NaN         NaN     NaN   37.1536
# delta_price1                      437146    NaN         NaN     NaN    79.067
# price_sensitive                   463837    NaN         NaN     NaN   24.6459
# hoteluv                           689148    NaN         NaN     NaN   95.0927
# businessrate_pre                  483896    NaN         NaN     NaN  0.372717
# ordernum_oneyear                  447831    NaN         NaN     NaN   11.6421
# cr_pre                            660548    NaN         NaN     NaN   1.06291
# avgprice                          457261    NaN         NaN     NaN   422.459
# lowestprice                       687931    NaN         NaN     NaN   318.806
# firstorder_bu                     376993    NaN         NaN     NaN   11.6978
# customereval_pre2                 661312    NaN         NaN     NaN   3.04852
# delta_price2                      437750    NaN         NaN     NaN   77.2772
# commentnums_pre                   598368    NaN         NaN     NaN   1415.16
# customer_value_profit             439123    NaN         NaN     NaN   3.03841
# commentnums_pre2                  648457    NaN         NaN     NaN   1313.39
# cancelrate_pre                    653015    NaN         NaN     NaN  0.344422
# novoters_pre2                     657616    NaN         NaN     NaN    1787.2
# novoters_pre                      648956    NaN         NaN     NaN    1890.7
# ctrip_profits                     445187    NaN         NaN     NaN   4.20849
# deltaprice_pre2_t1                543180    NaN         NaN     NaN   3.28374
# lowestprice_pre                   659689    NaN         NaN     NaN   315.955
# uv_pre                            660548    NaN         NaN     NaN   107.846
# uv_pre2                           661189    NaN         NaN     NaN   103.353
# lowestprice_pre2                  660664    NaN         NaN     NaN   318.542
# lasthtlordergap                   447831    NaN         NaN     NaN    101831
# businessrate_pre2                 602960    NaN         NaN     NaN  0.368237
# cityuvs                           682274    NaN         NaN     NaN   10.6483
# cityorders                        651263    NaN         NaN     NaN   2.25325
# lastpvgap                         592818    NaN         NaN     NaN   12049.4
# cr                                457896    NaN         NaN     NaN   1.13748
# sid                               689945    NaN         NaN     NaN   153.702
# visitnum_oneyear                  592910    NaN         NaN     NaN   18551.8
# h                                 689945    NaN         NaN     NaN   14.4623
#
#                                         std     min       1%     25%     50%  \
# label                              0.446238       0        0       0       0
# sampleid                             414681   24636  36205.9  312320  599637
# d                                       NaN     NaN      NaN     NaN     NaN
# arrival                                 NaN     NaN      NaN     NaN     NaN
# iforderpv_24h                      0.395226       0        0       0       0
# decisionhabit_user                  38.5245       0        1       2       3
# historyvisit_7ordernum              2.10386       1        1       1       1
# historyvisit_totalordernum          17.2514       1        1       2       6
# hotelcr                           0.0452643       1        1    1.03    1.05
# ordercanceledprecent                0.35421       0        0       0    0.25
# landhalfhours                       12.4132       0        0       0       0
# ordercanncelednum                   398.457       0        0       0       2
# commentnums                         2101.87       0        1     115     514
# starprefer                          19.1751       0       20    53.3    69.4
# novoters                            2811.69       1        1     157     692
# consuming_capacity                  23.2401       0        8      22      33
# historyvisit_avghotelnum            41.0453       0        1       2       4
# cancelrate                          1509.07       1        2     137     503
# historyvisit_visit_detailpagenum    73.4029       1        1       6      18
# delta_price1                        512.943  -99879 -1227.55     -31      81
# price_sensitive                     26.6856       0        0       5      16
# hoteluv                             169.982   0.007    0.167  10.427   36.18
# businessrate_pre                   0.232791       0     0.01    0.15    0.39
# ordernum_oneyear                    17.1372       1        1       2       6
# cr_pre                            0.0445878       1        1    1.03    1.06
# avgprice                            290.853       1       91     232     350
# lowestprice                         575.782      -3       37     116     200
# firstorder_bu                       2.74682       1        3      12      13
# customereval_pre2                   1.22664       0        0       2       3
# delta_price2                        391.414  -43344     -949     -29      69
# commentnums_pre                     2329.42       0        1     137     592
# customer_value_profit               6.62528 -24.075 -0.29678   0.269   0.991
# commentnums_pre2                    1719.51       0        3     270     768
# cancelrate_pre                     0.179147       0     0.05    0.23    0.32
# novoters_pre2                       2316.71       1        5     391    1054
# novoters_pre                        3116.12       1        2     187     783
# ctrip_profits                       9.31444 -44.313   -0.393    0.34   1.347
# deltaprice_pre2_t1                  48.8059   -2296     -103      -3       2
# lowestprice_pre                     463.724       1       38     118     208
# uv_pre                              186.732   0.007     0.24  12.533    42.5
# uv_pre2                             157.118   0.007      0.5  17.563  51.287
# lowestprice_pre2                    351.913       1       52     145     233
# lasthtlordergap                      122784       0      244   14999   46890
# businessrate_pre2                  0.219945       0     0.01    0.17     0.4
# cityuvs                             15.6967   0.007    0.013   0.827   3.527
# cityorders                          3.53845   0.007    0.007   0.127   0.627
# lastpvgap                           25601.4       0        0     551    2848
# cr                                 0.204789       1        1       1    1.05
# sid                                 277.808       0        1      17      62
# visitnum_oneyear                     228860       1       21     471    1315
# h                                   6.30158       0        0      11      15
#
#                                       75%          99%          max
# label                                   1            1            1
# sampleid                           887460  2.22689e+06  2.23843e+06
# d                                     NaN          NaN          NaN
# arrival                               NaN          NaN          NaN
# iforderpv_24h                           0            1            1
# decisionhabit_user                      5           27         3167
# historyvisit_7ordernum                  2            7          106
# historyvisit_totalordernum             14           82          711
# hotelcr                              1.09         1.19         3.18
# ordercanceledprecent                 0.57            1            1
# landhalfhours                           4           48           49
# ordercanncelednum                     153         1752        13475
# commentnums                          1670         8796        34189
# starprefer                           80.3          100          100
# novoters                             2196        11576        45455
# consuming_capacity                     51          100          100
# historyvisit_avghotelnum                7           29         3167
# cancelrate                           1373         6399        18930
# historyvisit_visit_detailpagenum       44          262         6199
# delta_price1                          226         1081         5398
# price_sensitive                        33          100          100
# hoteluv                           107.747      964.113      1722.61
# businessrate_pre                     0.57          0.8         0.99
# ordernum_oneyear                       14           81          711
# cr_pre                               1.09         1.19         2.95
# avgprice                              524         1491         6383
# lowestprice                           380         1823       100000
# firstorder_bu                          13           17           21
# customereval_pre2                       4          5.5            6
# delta_price2                          198         1018         5114
# commentnums_pre                      1862         9732        34189
# customer_value_profit               3.138       28.451      598.064
# commentnums_pre2                     1780         7457        34189
# cancelrate_pre                       0.42            1            1
# novoters_pre2                        2413        10018        45436
# novoters_pre                         2453        13839        45436
# ctrip_profits                        4.32      40.7558       600.82
# deltaprice_pre2_t1                     10          111         3324
# lowestprice_pre                       385         1750       100000
# uv_pre                            124.707      1047.79      1722.61
# uv_pre2                             126.2      856.725      1722.61
# lowestprice_pre2                      388         1464        43700
# lasthtlordergap                    138953       484734       527026
# businessrate_pre2                    0.55         0.78         0.99
# cityuvs                            13.327       66.007        67.14
# cityorders                          2.747       14.453       14.507
# lastpvgap                           10726       138722       194386
# cr                                   1.21            2           11
# sid                                   180         1212         9956
# visitnum_oneyear                     3141       262567  9.65119e+06
# h                                      20           23           23

# %% [markdown]
# **定义盖帽法处理异常值**

# %%
data.loc[:,['lowestprice','lowestprice_pre']].describe([0.01,0.25,0.5,0.75,0.99],include='all').T
# Out:
#                     count        mean         std  min    1%    25%    50%  \
# lowestprice      687931.0  318.806242  575.782415 -3.0  37.0  116.0  200.0
# lowestprice_pre  659689.0  315.954583  463.723643  1.0  38.0  118.0  208.0
#
#                    75%     99%       max
# lowestprice      380.0  1823.0  100000.0
# lowestprice_pre  385.0  1750.0  100000.0

# %%
col_01 = ['lowestprice','lowestprice_pre'] # 偏态严重

# %%
def block_lower(x):
# x是输⼊入的Series对象,替换1%分位数
    ql = x.quantile(.01)
    out = x.mask(x<ql,ql)
    return(out)

# %%
def block_upper(x):
# x是输⼊入的Series对象,l替换99%分位数
    qu = x.quantile(.99)
    out = x.mask(x>qu,qu)
    return(out)

# %%
data.loc[:,col_01]=data.loc[:,col_01].apply(block_upper)

# %%
data.loc[:,col_01]=data.loc[:,col_01].apply(block_lower)

# %%
data.loc[:,['lowestprice','lowestprice_pre']].describe([0.01,0.25,0.5,0.75,0.99],include='all').T
# Out:
#                     count        mean         std  min    1%    25%    50%  \
# lowestprice      687931.0  304.910234  297.490630 -3.0  37.0  116.0  200.0
# lowestprice_pre  659689.0  304.318020  287.309392  1.0  38.0  118.0  208.0
#
#                    75%     99%     max
# lowestprice      380.0  1823.0  1823.0
# lowestprice_pre  385.0  1750.0  1750.0

# %%
# data = data[data['lowestprice_pre']>=38]
# data = data[data['lowestprice']>=37]

# %%
data.head()
# Out:
#    label  sampleid           d     arrival  iforderpv_24h  decisionhabit_user  \
# 0      0     24636  2016-05-18  2016-05-18              0                 NaN
# 1      1     24637  2016-05-18  2016-05-18              0                 NaN
# 2      0     24641  2016-05-18  2016-05-19              0                 NaN
# 3      0     24642  2016-05-18  2016-05-18              0                 NaN
# 4      1     24644  2016-05-18  2016-05-19              0                 NaN
#
#    historyvisit_7ordernum  historyvisit_totalordernum  hotelcr  \
# 0                     NaN                         NaN     1.04
# 1                     NaN                         NaN     1.06
# 2                     NaN                         NaN     1.05
# 3                     NaN                         NaN     1.01
# 4                     NaN                         NaN     1.00
#
#    ordercanceledprecent  ...  lowestprice_pre2  lasthtlordergap  \
# 0                   NaN  ...             615.0              NaN
# 1                   NaN  ...             513.0              NaN
# 2                   NaN  ...             382.0              NaN
# 3                   NaN  ...             203.0              NaN
# 4                   NaN  ...              84.0              NaN
#
#    businessrate_pre2  cityuvs  cityorders  lastpvgap  cr  sid  \
# 0               0.29   12.880       3.147        NaN NaN    7
# 1               0.53   17.933       4.913        NaN NaN   33
# 2               0.60    3.993       0.760        NaN NaN   10
# 3               0.18    3.220       0.660        NaN NaN    8
# 4                NaN    0.013         NaN        NaN NaN    1
#
#    visitnum_oneyear   h
# 0               NaN  12
# 1               NaN  14
# 2               NaN  19
# 3               NaN  16
# 4               NaN  21
#
# [5 rows x 51 columns]

# %%
import datetime

# %%
data['delta'] = data.arrival.map(str_date) - data.d.map(str_date)

# %%
def str_date(x):
    return datetime.datetime.strptime(x,'%Y-%m-%d')

# %%
data['delta'] = data['delta'].dt.days

# %%
data.head()
# Out:
#    label  sampleid           d     arrival  iforderpv_24h  decisionhabit_user  \
# 0      0     24636  2016-05-18  2016-05-18              0                 NaN
# 1      1     24637  2016-05-18  2016-05-18              0                 NaN
# 2      0     24641  2016-05-18  2016-05-19              0                 NaN
# 3      0     24642  2016-05-18  2016-05-18              0                 NaN
# 4      1     24644  2016-05-18  2016-05-19              0                 NaN
#
#    historyvisit_7ordernum  historyvisit_totalordernum  hotelcr  \
# 0                     NaN                         NaN     1.04
# 1                     NaN                         NaN     1.06
# 2                     NaN                         NaN     1.05
# 3                     NaN                         NaN     1.01
# 4                     NaN                         NaN     1.00
#
#    ordercanceledprecent  ...  lasthtlordergap  businessrate_pre2  cityuvs  \
# 0                   NaN  ...              NaN               0.29   12.880
# 1                   NaN  ...              NaN               0.53   17.933
# 2                   NaN  ...              NaN               0.60    3.993
# 3                   NaN  ...              NaN               0.18    3.220
# 4                   NaN  ...              NaN                NaN    0.013
#
#    cityorders  lastpvgap  cr  sid  visitnum_oneyear   h  delta
# 0       3.147        NaN NaN    7               NaN  12      0
# 1       4.913        NaN NaN   33               NaN  14      0
# 2       0.760        NaN NaN   10               NaN  19      1
# 3       0.660        NaN NaN    8               NaN  16      0
# 4         NaN        NaN NaN    1               NaN  21      1
#
# [5 rows x 52 columns]

# %%
data['M'] = data.avgprice * data.ordernum_oneyear

# %%
data.drop(columns=['d','arrival','avgprice','ordernum_oneyear'],axis=1,inplace=True)

# %%
data.drop(columns=['sampleid'],inplace=True)

# %%
data.head()
# Out:
#    label  iforderpv_24h  decisionhabit_user  historyvisit_7ordernum  \
# 0      0              0                 NaN                     NaN
# 1      1              0                 NaN                     NaN
# 2      0              0                 NaN                     NaN
# 3      0              0                 NaN                     NaN
# 4      1              0                 NaN                     NaN
#
#    historyvisit_totalordernum  hotelcr  ordercanceledprecent  landhalfhours  \
# 0                         NaN     1.04                   NaN           22.0
# 1                         NaN     1.06                   NaN            0.0
# 2                         NaN     1.05                   NaN            3.0
# 3                         NaN     1.01                   NaN            2.0
# 4                         NaN     1.00                   NaN            0.0
#
#    ordercanncelednum  commentnums  ...  businessrate_pre2  cityuvs  \
# 0                NaN       1089.0  ...               0.29   12.880
# 1                NaN       5612.0  ...               0.53   17.933
# 2                NaN        256.0  ...               0.60    3.993
# 3                NaN          NaN  ...               0.18    3.220
# 4                NaN          NaN  ...                NaN    0.013
#
#    cityorders  lastpvgap  cr  sid  visitnum_oneyear   h  delta   M
# 0       3.147        NaN NaN    7               NaN  12      0 NaN
# 1       4.913        NaN NaN   33               NaN  14      0 NaN
# 2       0.760        NaN NaN   10               NaN  19      1 NaN
# 3       0.660        NaN NaN    8               NaN  16      0 NaN
# 4         NaN        NaN NaN    1               NaN  21      1 NaN
#
# [5 rows x 48 columns]

# %%
data_copy = data.copy() # 备份数据

# %%
data_cr_null = data[data.cr.isna()]

# %%
data_cr = data[data.cr.notnull()]

# %%
data_cr.shape
# Out:
# (457896, 48)

# %%
X = data_cr.drop(columns=['cr'],axis=1)
y = data_cr.cr

from sklearn.model_selection import train_test_split

Xtrain,Xtest,Ytrain,Ytest = train_test_split(X,y,test_size=0.3,random_state=666)

# %%
Xtrain = Xtrain.reset_index(drop=True)
Xtest = Xtest.reset_index(drop=True)
Ytrain = Ytrain.reset_index(drop=True)
Ytest = Ytest.reset_index(drop=True)

# %%
data.isna().mean().reset_index().sort_values(by=0)
# Out:
#                                index         0
# 0                              label  0.000000
# 1                      iforderpv_24h  0.000000
# 45                                 h  0.000000
# 43                               sid  0.000000
# 46                             delta  0.000000
# 5                            hotelcr  0.001155
# 18                           hoteluv  0.001155
# 21                       lowestprice  0.002919
# 39                           cityuvs  0.011118
# 14                        cancelrate  0.016984
# 11                          novoters  0.024679
# 23                 customereval_pre2  0.041500
# 7                      landhalfhours  0.041500
# 35                           uv_pre2  0.041679
# 36                  lowestprice_pre2  0.042440
# 34                            uv_pre  0.042608
# 20                            cr_pre  0.042608
# 33                   lowestprice_pre  0.043853
# 29                     novoters_pre2  0.046857
# 28                    cancelrate_pre  0.053526
# 40                        cityorders  0.056065
# 30                      novoters_pre  0.059409
# 27                  commentnums_pre2  0.060132
# 9                        commentnums  0.098437
# 38                 businessrate_pre2  0.126075
# 25                   commentnums_pre  0.132731
# 44                  visitnum_oneyear  0.140642
# 41                         lastpvgap  0.140775
# 32                deltaprice_pre2_t1  0.212720
# 19                  businessrate_pre  0.298646
# 10                        starprefer  0.326190
# 12                consuming_capacity  0.327719
# 17                   price_sensitive  0.327719
# 42                                cr  0.336330
# 6               ordercanceledprecent  0.350918
# 8                  ordercanncelednum  0.350918
# 37                   lasthtlordergap  0.350918
# 31                     ctrip_profits  0.354750
# 26             customer_value_profit  0.363539
# 24                      delta_price2  0.365529
# 16                      delta_price1  0.366405
# 47                                 M  0.381943
# 13          historyvisit_avghotelnum  0.437816
# 4         historyvisit_totalordernum  0.439774
# 2                 decisionhabit_user  0.441332
# 22                     firstorder_bu  0.453590
# 15  historyvisit_visit_detailpagenum  0.554698
# 3             historyvisit_7ordernum  0.879824

# %%
date_train.to_csv('date_train.csv')
date_test.to_csv('date_test.csv')

# %%
col_no = ['sid','iforderpv_24h','h'] #没有缺失值的特征
col_clf = ['decisionhabit_user'] # 分类型变量
col_neg = ['delta_price1','delta_price2','customer_value_profit'
           ,'ctrip_profits','deltaprice_pre2_t1'] # 含有负数
col_std = Xtrain.columns[Xtrain.describe(include='all').T['std'] >100].to_list() # std >100
col_std.remove('delta_price1')
col_std.remove('delta_price2')
col_std.remove('lasthtlordergap')

# %%
col_35 = ['firstorder_bu','decisionhabit_user','historyvisit_totalordernum'
 ,'historyvisit_avghotelnum','customer_value_profit','ctrip_profits'
 ,'lasthtlordergap','ordercanceledprecent','ordercanncelednum','M'] # 缺失35% —— 55%

# %%
cols = X.columns.to_list()

col_norm = list(set(cols)-set(col_clf + col_std + col_neg + col_no +col_35))

# %% [markdown]
# ## 缺失值填补

# %% [markdown]
# - 分类型变量用 '众数填补' —— col_clf
# - 含有负数的特征用 '中值填补' —— col_neg
# - std > 100 方差大于100的连续型变量用 '中值填补' —— col_std
# - 缺失35%——55%用 '常数 -1 填充' 单独做一类
# - 其余变量用 '均值填补' —— col_norm

# %%
Xtrain.loc[:,col_clf] = Xtrain.loc[:,col_clf].fillna(Xtrain.loc[:,col_clf].mode())

Xtrain.loc[:,col_neg] = Xtrain.loc[:,col_neg].fillna(Xtrain.loc[:,col_neg].median())

Xtrain.loc[:,col_std] = Xtrain.loc[:,col_std].fillna(Xtrain.loc[:,col_std].median())

Xtrain.loc[:,col_norm] = Xtrain.loc[:,col_norm].fillna(Xtrain.loc[:,col_norm].mean())

Xtrain.loc[:,col_35] = Xtrain.loc[:,col_35].fillna(-1)

# %%
Xtest.loc[:,col_clf] = Xtest.loc[:,col_clf].fillna(Xtest.loc[:,col_clf].mode())

# %%
Xtest.loc[:,col_neg] = Xtest.loc[:,col_neg].fillna(Xtest.loc[:,col_neg].median())

# %%
Xtest.loc[:,col_std] = Xtest.loc[:,col_std].fillna(Xtest.loc[:,col_std].median())

# %%
Xtest.loc[:,col_norm] = Xtest.loc[:,col_norm].fillna(Xtest.loc[:,col_norm].mean())

# %%
Xtest.loc[:,col_35] = Xtest.loc[:,col_35].fillna(-1)

# %% [markdown]
# **检查缺失值填补情况**

# %%
Xtrain.isna().any().sum()
# Out:
# 0

# %%
Xtest.isna().any().sum()
# Out:
# 0

# %%
# 特征创造
# ordernum_oneyear_train = Xtrain.loc[:,'ordernum_oneyear'].reset_index(drop=True)
# ordernum_oneyear_test = Xtest.loc[:,'ordernum_oneyear'].reset_index(drop=True)
# avgprice_train = Xtrain.loc[:,'avgprice'].reset_index(drop=True)
# avgprice_test = Xtest.loc[:,'avgprice'].reset_index(drop=True)

# M_train = ordernum_oneyear_train * avgprice_train

# M_test = ordernum_oneyear_test * avgprice_test

# M_train.to_csv('M_train.csv')
# M_test.to_csv('M_test.csv')
# Out:
# /Users/jim/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   if sys.path[0] == '':

# %% [markdown]
# ## 特征选择

# %%
Xtrain.to_excel('Xtrain.xlsx')
Xtest.to_excel('Xtest.xlsx')
Ytrain.to_excel('Ytrain.xlsx')
Ytest.to_excel('Ytest.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-0d5b7bdaa320> in <module>
# ----> 1 Xtrain.to_excel('Xtrain.xlsx')
#       2 Xtest.to_excel('Xtest.xlsx')
#       3 Ytrain.to_excel('Ytrain.xlsx')
#       4 Ytest.to_excel('Ytest.xlsx')
#
# D:\DataFrame\Anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2254             startcol=startcol,
#    2255             freeze_panes=freeze_panes,
# -> 2256             engine=engine,
#    2257         )
#    2258
#
# D:\DataFrame\Anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     737             startrow=startrow,
#     738             startcol=startcol,
# --> 739             freeze_panes=freeze_panes,
#     740         )
#     741         if need_save:
#
# D:\DataFrame\Anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#     235                 )
#     236             else:
# --> 237                 wks.write(startrow + cell.row, startcol + cell.col, val, style)
#
# D:\DataFrame\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py in cell_wrapper(self, *args, **kwargs)
#      67             args = new_args + args[1:]
#      68
# ---> 69         return method(self, *args, **kwargs)
#      70
#      71     return cell_wrapper
#
# KeyboardInterrupt:

# %%
y.value_counts()
# Out:
# 1.00    214775
# 1.33     15339
# 1.25     14438
# 1.50     13226
# 1.17     12711
#          ...
# 2.60         1
# 2.80         1
# 2.83         1
# 4.67         1
# 1.91         1
# Name: cr, Length: 115, dtype: int64

# %%
500588/189357
# Out:
# 2.6436202516938905

# %%
y.shape
# Out:
# (647450,)

# %%
X.shape
# Out:
# (647450, 46)

# %%
Xtrain.describe().T
# Out:
#                                      count          mean            std  \
# label                             320527.0      0.282550       0.450240
# iforderpv_24h                     320527.0      0.171876       0.377273
# decisionhabit_user                320527.0      4.178525      32.209462
# historyvisit_7ordernum            320527.0      1.880474       0.899453
# historyvisit_totalordernum        320527.0      9.474219      16.529539
# hotelcr                           320527.0      1.063332       0.045913
# ordercanceledprecent              320527.0      0.061573       0.627946
# landhalfhours                     320527.0      5.976185      12.247514
# ordercanncelednum                 320527.0    127.962315     359.409402
# commentnums                       320527.0   1255.455185    2089.277623
# starprefer                        320527.0     68.183503      17.083307
# novoters                          320527.0   1762.342707    2890.185971
# consuming_capacity                320527.0     39.723987      21.004138
# historyvisit_avghotelnum          320527.0      5.221827      35.103098
# cancelrate                        320527.0   1092.385434    1542.472139
# historyvisit_visit_detailpagenum  320527.0     38.076264      57.470114
# delta_price1                      320527.0     81.492735     413.559268
# price_sensitive                   320527.0     24.693918      23.716152
# hoteluv                           320527.0     97.486809     172.983010
# businessrate_pre                  320527.0      0.390445       0.194453
# cr_pre                            320527.0      1.065175       0.044146
# lowestprice                       320527.0    318.047640     308.628468
# firstorder_bu                     320527.0      6.979131       6.518966
# customereval_pre2                 320527.0      3.132035       1.222014
# delta_price2                      320527.0     77.780234     340.122159
# commentnums_pre                   320527.0   1349.817204    2251.029077
# customer_value_profit             320527.0      2.757469       6.085409
# commentnums_pre2                  320527.0   1328.459712    1753.418432
# cancelrate_pre                    320527.0      0.341499       0.172501
# novoters_pre2                     320527.0   1824.474019    2383.964705
# novoters_pre                      320527.0   1886.362459    3115.012317
# ctrip_profits                     320527.0      3.837848       8.512409
# deltaprice_pre2_t1                320527.0      3.344779      47.854122
# lowestprice_pre                   320527.0    313.555410     293.351960
# uv_pre                            320527.0    106.056935     183.968702
# uv_pre2                           320527.0    102.670469     158.273376
# lowestprice_pre2                  320527.0    328.885420     362.850296
# lasthtlordergap                   320527.0  70565.838519  105857.420101
# businessrate_pre2                 320527.0      0.387269       0.204412
# cityuvs                           320527.0     10.847127      15.866658
# cityorders                        320527.0      2.321370       3.497657
# lastpvgap                         320527.0   8505.815338   15846.275983
# sid                               320527.0    186.408889     294.586407
# visitnum_oneyear                  320527.0   3758.647973   53994.847358
# h                                 320527.0     14.665785       6.146250
# delta                             320527.0      3.475851       6.555837
# M                                 320527.0   4785.968948    8444.996030
#
#                                         min          25%           50%  \
# label                                 0.000     0.000000      0.000000
# iforderpv_24h                         0.000     0.000000      0.000000
# decisionhabit_user                   -1.000     1.000000      2.000000
# historyvisit_7ordernum                1.000     1.880474      1.880474
# historyvisit_totalordernum           -1.000     1.000000      4.000000
# hotelcr                               1.000     1.030000      1.060000
# ordercanceledprecent                 -1.000     0.000000      0.040000
# landhalfhours                         0.000     0.000000      0.000000
# ordercanncelednum                     0.000     1.000000      2.000000
# commentnums                           0.000   155.000000    555.000000
# starprefer                            0.000    60.000000     68.183503
# novoters                              1.000   181.000000    747.000000
# consuming_capacity                    0.000    25.000000     39.723987
# historyvisit_avghotelnum             -1.000     1.000000      3.000000
# cancelrate                            1.000   154.000000    542.000000
# historyvisit_visit_detailpagenum      1.000    13.000000     38.076264
# delta_price1                     -43344.000    12.000000     83.000000
# price_sensitive                       0.000     8.000000     23.000000
# hoteluv                               0.007    10.847000     37.280000
# businessrate_pre                      0.000     0.290000      0.390445
# cr_pre                                1.000     1.030000      1.060000
# lowestprice                          37.000   119.000000    212.000000
# firstorder_bu                        -1.000    -1.000000     12.000000
# customereval_pre2                     0.000     2.100000      3.132035
# delta_price2                     -43344.000    11.000000     72.000000
# commentnums_pre                       0.000   194.000000    627.000000
# customer_value_profit               -24.075     0.456000      1.097000
# commentnums_pre2                      0.000   299.000000    794.000000
# cancelrate_pre                        0.000     0.230000      0.330000
# novoters_pre2                         1.000   423.000000   1091.000000
# novoters_pre                          1.000   225.000000    835.000000
# ctrip_profits                       -27.007     0.627000      1.513000
# deltaprice_pre2_t1                -2296.000     0.000000      2.000000
# lowestprice_pre                      38.000   121.000000    218.000000
# uv_pre                                0.007    13.436500     42.873000
# uv_pre2                               0.007    18.073000     50.412000
# lowestprice_pre2                      1.000   151.000000    241.000000
# lasthtlordergap                      -1.000  1612.000000  24917.000000
# businessrate_pre2                     0.000     0.240000      0.387269
# cityuvs                               0.007     0.807000      3.647000
# cityorders                            0.007     0.140000      0.787000
# lastpvgap                             0.000   540.000000   2303.000000
# sid                                   1.000    33.000000     92.000000
# visitnum_oneyear                      1.000   590.000000   1418.000000
# h                                     0.000    11.000000     16.000000
# delta                                 0.000     0.000000      0.000000
# M                                     3.000  1253.500000   2403.000000
#
#                                            75%          max
# label                                 1.000000        1.000
# iforderpv_24h                         0.000000        1.000
# decisionhabit_user                    5.000000     2383.000
# historyvisit_7ordernum                1.880474      106.000
# historyvisit_totalordernum           11.000000      711.000
# hotelcr                               1.090000        3.180
# ordercanceledprecent                  0.500000        1.000
# landhalfhours                         5.976185       49.000
# ordercanncelednum                    38.000000    11996.000
# commentnums                        1577.000000    34189.000
# starprefer                           80.000000      100.000
# novoters                           2282.000000    45455.000
# consuming_capacity                   46.000000      100.000
# historyvisit_avghotelnum              6.000000     2666.700
# cancelrate                         1434.000000    18930.000
# historyvisit_visit_detailpagenum     38.076264     6199.000
# delta_price1                        171.000000     5398.000
# price_sensitive                      28.000000      100.000
# hoteluv                             111.520000     1722.613
# businessrate_pre                      0.520000        0.990
# cr_pre                                1.090000        2.950
# lowestprice                         398.000000     1823.000
# firstorder_bu                        13.000000       21.000
# customereval_pre2                     4.000000        6.000
# delta_price2                        150.000000     4843.000
# commentnums_pre                    1667.000000    34189.000
# customer_value_profit                 2.411000      598.064
# commentnums_pre2                   1762.000000    34189.000
# cancelrate_pre                        0.410000        1.000
# novoters_pre2                      2433.000000    45436.000
# novoters_pre                       2412.000000    45436.000
# ctrip_profits                         3.313000      600.820
# deltaprice_pre2_t1                    8.000000     3324.000
# lowestprice_pre                     390.000000     1750.000
# uv_pre                              120.753000     1722.613
# uv_pre2                             122.873000     1722.613
# lowestprice_pre2                    396.000000    43700.000
# lasthtlordergap                   88273.500000   527026.000
# businessrate_pre2                     0.540000        0.990
# cityuvs                              13.327000       67.140
# cityorders                            2.673000       14.507
# lastpvgap                          8874.000000   194113.000
# sid                                 226.000000     8996.000
# visitnum_oneyear                   3076.000000  7274128.000
# h                                    20.000000       23.000
# delta                                 3.000000       30.000
# M                                  4545.000000   297198.000

# %% [markdown]
# ### 方差过滤

# %%
from sklearn.feature_selection import VarianceThreshold
selector = VarianceThreshold()
Xtrain_var0 = selector.fit(Xtrain).transform(Xtrain)

# %%
Xtrain.shape
# Out:
# (320527, 47)

# %%
Xtrain_var0.shape
# Out:
# (320527, 47)

# %% [markdown]
# ### F_检验

# %%
from sklearn.feature_selection import f_classif
F , pvalues_f = f_classif(Xtrain,Ytrain)

# %%
F
# Out:
# array([ 206.7622291 ,   10.27884697,    2.33442789,   58.80123547,
#        1503.02475229,   48.84699778,  564.67973272,   16.33577268,
#         316.89664865,    6.95299541,   46.76516291,    6.99029345,
#          56.29418372,    6.27122457,    8.21823879,   43.41427764,
#           2.31894858,    8.38540735,   18.67412176,   72.209704  ,
#          51.55222905,   27.36273501,   76.57368522,   49.2534399 ,
#           3.2743382 ,    7.83509262,  341.43198943,   10.50877719,
#          13.34284381,    9.80247321,    7.39048211,  242.41162352,
#           3.80741213,   25.19155865,   19.89290807,   23.05993279,
#          20.54089377,  430.72725723,   94.69692494,   23.17567004,
#          24.67577213,  131.86418354,  156.10467757,    6.03575254,
#           6.53941711,   92.10619952,  728.66311592])

# %%
pvalues_f
# Out:
# array([0.00000000e+000, 1.33983961e-171, 5.79606720e-014, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 3.16517104e-307,
#        0.00000000e+000, 3.04178453e-100, 0.00000000e+000, 5.07374449e-101,
#        0.00000000e+000, 3.75211445e-086, 5.82382674e-127, 0.00000000e+000,
#        9.60568271e-014, 1.54806649e-130, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        8.33267981e-029, 8.37725214e-119, 0.00000000e+000, 1.20447214e-176,
#        1.29237350e-239, 3.50659398e-161, 2.08720359e-109, 0.00000000e+000,
#        3.51376831e-038, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 2.39730228e-081,
#        1.15089857e-091, 0.00000000e+000, 0.00000000e+000])

# %% [markdown]
# **与标签没有显著相关性的变量有6个**

# %%
(pvalues_f>0.01).sum()
# Out:
# 0

# %% [markdown]
# **剔除没有相关性的变量**

# %%
col_f = list(Xtrain.columns[pvalues_f<0.01])
col_f
# Out:
# ['label',
#  'iforderpv_24h',
#  'decisionhabit_user',
#  'historyvisit_7ordernum',
#  'historyvisit_totalordernum',
#  'hotelcr',
#  'ordercanceledprecent',
#  'landhalfhours',
#  'ordercanncelednum',
#  'commentnums',
#  'starprefer',
#  'novoters',
#  'consuming_capacity',
#  'historyvisit_avghotelnum',
#  'cancelrate',
#  'historyvisit_visit_detailpagenum',
#  'delta_price1',
#  'price_sensitive',
#  'hoteluv',
#  'businessrate_pre',
#  'cr_pre',
#  'lowestprice',
#  'firstorder_bu',
#  'customereval_pre2',
#  'delta_price2',
#  'commentnums_pre',
#  'customer_value_profit',
#  'commentnums_pre2',
#  'cancelrate_pre',
#  'novoters_pre2',
#  'novoters_pre',
#  'ctrip_profits',
#  'deltaprice_pre2_t1',
#  'lowestprice_pre',
#  'uv_pre',
#  'uv_pre2',
#  'lowestprice_pre2',
#  'lasthtlordergap',
#  'businessrate_pre2',
#  'cityuvs',
#  'cityorders',
#  'lastpvgap',
#  'sid',
#  'visitnum_oneyear',
#  'h',
#  'delta',
#  'M']

# %%
Xtrain = Xtrain.loc[:,col_f]

# %%
Xtest = Xtest.loc[:,col_f]

# %%
# Xtrain.index = range(Xtrain.shape[0]) # 重置索引
# Xtrain
# Out:
#         iforderpv_24h  historyvisit_totalordernum  hotelcr  \
# 0                   0                        -1.0     1.01
# 1                   0                        -1.0     1.06
# 2                   0                        16.0     1.04
# 3                   0                         1.0     1.01
# 4                   1                         8.0     1.13
# ...               ...                         ...      ...
# 453210              0                        -1.0     1.03
# 453211              0                        74.0     1.01
# 453212              1                        -1.0     1.08
# 453213              0                         2.0     1.00
# 453214              0                         3.0     1.06
#
#         ordercanceledprecent  landhalfhours  ordercanncelednum  starprefer  \
# 0                      -1.00            0.0                2.0   67.554105
# 1                       0.19            3.0               63.0   82.400000
# 2                       0.43           30.0              571.0   96.400000
# 3                       0.00            0.0                0.0   68.000000
# 4                       0.98            0.0              293.0   56.400000
# ...                      ...            ...                ...         ...
# 453210                  0.01            2.0                1.0   30.000000
# 453211                  0.55            7.0             2367.0   57.900000
# 453212                 -1.00           38.0                2.0   67.554105
# 453213                  0.00            0.0                0.0   40.000000
# 453214                  0.67            0.0                2.0   64.000000
#
#         consuming_capacity  cancelrate  delta_price1  ...  lowestprice_pre2  \
# 0                39.125564        89.0          81.0  ...             172.0
# 1                72.000000      3978.0         107.0  ...             354.0
# 2                69.000000      3428.0          37.0  ...             395.0
# 3                31.000000       321.0        -144.0  ...             530.0
# 4                25.000000       689.0          72.0  ...             185.0
# ...                    ...         ...           ...  ...               ...
# 453210           21.000000      2111.0         -55.0  ...             236.0
# 453211           31.000000        11.0         137.0  ...             203.0
# 453212           39.125564      1789.0          81.0  ...             306.0
# 453213           22.000000         2.0          41.0  ...             223.0
# 453214           25.000000      1949.0         121.0  ...             160.0
#
#         lasthtlordergap  businessrate_pre2  cityuvs  cityorders  lastpvgap  \
# 0                  -1.0           0.050000    2.267       0.133        0.0
# 1               23823.0           0.550000   25.080       3.353     1753.0
# 2               30793.0           0.230000   10.747       1.613    30792.0
# 3              355113.0           0.300000    0.913       0.140      806.0
# 4              161858.0           0.810000    0.107       0.007    19664.0
# ...                 ...                ...      ...         ...        ...
# 453210         135349.0           0.120000    1.747       0.107     1182.0
# 453211           3243.0           0.650000   11.073       2.147     1509.0
# 453212             -1.0           0.390000    8.547       1.400     2858.0
# 453213         120184.0           0.370167   20.513       4.347    27707.0
# 453214         167434.0           0.360000    0.507       0.053       35.0
#
#               cr  sid  visitnum_oneyear   h
# 0       1.139221   27            1050.0   0
# 1       1.139221  257            5780.0  14
# 2       1.200000  205            3616.0  11
# 3       1.000000  184            1064.0  13
# 4       1.000000  286            1468.0  14
# ...          ...  ...               ...  ..
# 453210  1.139221  128           13213.0   2
# 453211  1.380000  727            8826.0  20
# 453212  1.139221    1            1306.0  20
# 453213  2.000000    5            1295.0   0
# 453214  1.000000   70            1422.0  19
#
# [453215 rows x 40 columns]

# %%
# Ytrain = Ytrain.reset_index(drop=True)

# %%
# Xtest.index = range(Xtest.shape[0]) # 重置索引
# Xtest.head()
# Out:
#    iforderpv_24h  historyvisit_totalordernum  hotelcr  ordercanceledprecent  \
# 0              1                         5.0     1.07                  0.60
# 1              0                        -1.0     1.08                 -1.00
# 2              0                         1.0     1.02                  0.00
# 3              0                         2.0     1.11                  0.00
# 4              0                        28.0     1.12                  0.29
#
#    landhalfhours  ordercanncelednum  starprefer  consuming_capacity  \
# 0           46.0                3.0   40.000000            9.000000
# 1           39.0                2.0   67.541185           39.083482
# 2            9.0                0.0   40.000000           16.000000
# 3            0.0                0.0   80.000000           51.000000
# 4            0.0              107.0   88.800000           51.000000
#
#    cancelrate  delta_price1  ...  lowestprice_pre2  lasthtlordergap  \
# 0      3415.0        -308.0  ...             501.0           1116.0
# 1       376.0          79.0  ...             120.0             -1.0
# 2       479.0          40.0  ...             247.0         198614.0
# 3       378.0         284.0  ...             152.0          16440.0
# 4      1422.0         588.0  ...             222.0           5079.0
#
#    businessrate_pre2  cityuvs  cityorders  lastpvgap        cr  sid  \
# 0               0.50   56.487      12.653       19.0  1.020000  814
# 1               0.56    2.567       0.280     2862.0  1.138505    2
# 2               0.47   21.747       3.133     8856.0  1.000000   73
# 3               0.54   17.933       4.913      222.0  1.250000   33
# 4               0.33    0.213       0.020     1869.0  1.190000   85
#
#    visitnum_oneyear   h
# 0            6408.0   5
# 1            1292.0  11
# 2             345.0  23
# 3             325.0  15
# 4            9218.0  16
#
# [5 rows x 40 columns]

# %%
# Ytest = Ytest.reset_index(drop=True)

# %%
Xtrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320527 entries, 0 to 320526
# Data columns (total 47 columns):
# label                               320527 non-null int64
# iforderpv_24h                       320527 non-null int64
# decisionhabit_user                  320527 non-null float64
# historyvisit_7ordernum              320527 non-null float64
# historyvisit_totalordernum          320527 non-null float64
# hotelcr                             320527 non-null float64
# ordercanceledprecent                320527 non-null float64
# landhalfhours                       320527 non-null float64
# ordercanncelednum                   320527 non-null float64
# commentnums                         320527 non-null float64
# starprefer                          320527 non-null float64
# novoters                            320527 non-null float64
# consuming_capacity                  320527 non-null float64
# historyvisit_avghotelnum            320527 non-null float64
# cancelrate                          320527 non-null float64
# historyvisit_visit_detailpagenum    320527 non-null float64
# delta_price1                        320527 non-null float64
# price_sensitive                     320527 non-null float64
# hoteluv                             320527 non-null float64
# businessrate_pre                    320527 non-null float64
# cr_pre                              320527 non-null float64
# lowestprice                         320527 non-null float64
# firstorder_bu                       320527 non-null float64
# customereval_pre2                   320527 non-null float64
# delta_price2                        320527 non-null float64
# commentnums_pre                     320527 non-null float64
# customer_value_profit               320527 non-null float64
# commentnums_pre2                    320527 non-null float64
# cancelrate_pre                      320527 non-null float64
# novoters_pre2                       320527 non-null float64
# novoters_pre                        320527 non-null float64
# ctrip_profits                       320527 non-null float64
# deltaprice_pre2_t1                  320527 non-null float64
# lowestprice_pre                     320527 non-null float64
# uv_pre                              320527 non-null float64
# uv_pre2                             320527 non-null float64
# lowestprice_pre2                    320527 non-null float64
# lasthtlordergap                     320527 non-null float64
# businessrate_pre2                   320527 non-null float64
# cityuvs                             320527 non-null float64
# cityorders                          320527 non-null float64
# lastpvgap                           320527 non-null float64
# sid                                 320527 non-null int64
# visitnum_oneyear                    320527 non-null float64
# h                                   320527 non-null int64
# delta                               320527 non-null int64
# M                                   320527 non-null float64
# dtypes: float64(42), int64(5)
# memory usage: 114.9 MB

# %% [markdown]
# ### 嵌入法筛选特征

# %%
from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.model_selection import cross_val_score

# %%
# 初步探索
RFR_clf = RFR(n_estimators=10,random_state=0)
X_embedded = SelectFromModel(RFR_clf,threshold=0.05).fit_transform(Xtrain,Ytrain)

# %%
X_embedded.shape
# Out:
# (320527, 4)

# %% [markdown]
# **利用随机森林调出特征重要性**

# %%
time0 = time()
RFR_ = RFR(n_estimators=20,random_state=0)
importance = RFR_.fit(Xtrain,Ytrain).feature_importances_
print(datetime.datetime.fromtimestamp(time()-time0).strftime("%H:%M:%S"))
print(importance)
# Out:
# 08:05:25
# [0.01193139 0.00087381 0.01476569 0.00976014 0.0628667  0.00238884
#  0.10936049 0.00457226 0.01801109 0.00180483 0.01754188 0.00174504
#  0.01598576 0.02164425 0.00204481 0.01235362 0.00668768 0.01574712
#  0.00284652 0.00727034 0.0080307  0.00280261 0.00589767 0.0058689
#  0.007365   0.00638297 0.01597745 0.00578472 0.00516434 0.00479727
#  0.00505891 0.01630751 0.0063866  0.00800279 0.00529171 0.00624365
#  0.00581863 0.29352949 0.00760944 0.01161854 0.01163491 0.04875612
#  0.02394425 0.10637209 0.01194554 0.00716937 0.01603655]

# %%
importance.max()
# Out:
# 0.29352948526556477

# %%
Xtrain.shape
# Out:
# (453215, 40)

# %%
Ytrain.shape
# Out:
# (453215,)

# %%
from time import time
import datetime # 计时器

# %% [markdown]
# **嵌入法画学习曲线**

# %%
RFR_ = RFR(n_estimators=30,random_state=0)
importance = RFR_.fit(Xtrain,Ytrain).feature_importances_
threshold = np.linspace(0,importance.max(),20)
score = []
time0 = time()
for i in threshold:
    X_embedded = SelectFromModel(RFR_,threshold=i).fit_transform(Xtrain,Ytrain)
    val = cross_val_score(RFR_,X_embedded,Ytrain,cv=5).mean()
    score.append(val)
print(datetime.datetime.fromtimestamp(time()-time0).strftime("%H:%M:%S"))
print(score)
plt.figure(figsize=(8,6))
plt.plot(threshold,score)
plt.title('特征选择学习曲线')
plt.show();
# Out:
# findfont: Font family ['Arial Unicode MS'] not found. Falling back to DejaVu Sans.
# 09:46:00
# [0.875862906762816, 0.9074283215580937, 0.8954251331491431, 0.8954251331491431, 0.8870485462264439, 0.8795498933929295, 0.8795498933929295, 0.6692797439007672, 0.6692797439007672, 0.6692797439007672, 0.6692797439007672, 0.6692797439007672, 0.6692797439007672, 0.6692797439007672, 0.6692797439007672, 0.6692797439007672, 0.6692797439007672, 0.6692797439007672, 0.6692797439007672, 0.6692797439007672]
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 29305 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24449 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36873 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 25321 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23398 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26354 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32447 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 29305 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24449 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 36873 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 25321 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23398 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26354 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\DataFrame\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32447 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.figure(figsize=(8,6))
plt.plot(threshold,score)
plt.show()

# %%
np.max(score) #最高分
# Out:
# 0.9074283215580937

# %%
threshold[np.argmax(score)] #最高分对应的重要性阈值
# Out:
# 0.015423843595762458

# %%
X_embedded = SelectFromModel(RFR_,threshold=0.015423843595762458).fit_transform(Xtrain,Ytrain)

# %%
col_k = list(Xtrain.columns[RFR_.feature_importances_>0.015423843595762458])
col_k
# Out:
# ['historyvisit_totalordernum',
#  'ordercanceledprecent',
#  'ordercanncelednum',
#  'starprefer',
#  'historyvisit_avghotelnum',
#  'price_sensitive',
#  'customer_value_profit',
#  'ctrip_profits',
#  'lasthtlordergap',
#  'lastpvgap',
#  'sid',
#  'visitnum_oneyear',
#  'M']

# %%
len(col_k)
# Out:
# 13

# %% [markdown]
# **利用阈值选择出 13 个特征**

# %%
Xtrain_new = pd.DataFrame(X_embedded,columns = col_k )
Xtrain_new.head()
# Out:
#    historyvisit_totalordernum  ordercanceledprecent  ordercanncelednum  \
# 0                         2.0                  0.00                0.0
# 1                        82.0                  0.44             1614.0
# 2                        18.0                  0.29              310.0
# 3                        19.0                  0.11               12.0
# 4                         5.0                  0.20                1.0
#
#    starprefer  historyvisit_avghotelnum  price_sensitive  \
# 0        66.7                       8.0              0.0
# 1        68.1                       1.8             16.0
# 2        61.8                       9.7              9.0
# 3        56.0                       4.4             28.0
# 4        52.5                       4.1              5.0
#
#    customer_value_profit  ctrip_profits  lasthtlordergap  lastpvgap    sid  \
# 0                  0.224          0.220         297425.0        0.0   86.0
# 1                  6.149         -5.727          10585.0     2347.0  386.0
# 2                  3.625         10.320         125856.0      166.0  382.0
# 3                  2.175          2.107          42784.0      615.0   40.0
# 4                  4.282          8.360          32465.0     1665.0  230.0
#
#    visitnum_oneyear        M
# 0            3574.0    446.0
# 1            5721.0  27224.0
# 2             742.0   5940.0
# 3            4089.0   6840.0
# 4            3874.0   1980.0

# %%
Xtest_new = Xtest.loc[:,col_k].reset_index(drop=True)

# %% [markdown]
# **保存清洗后的数据**

# %%
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(Xtrain_new.corr(),annot=True,linewidths=1)

# %%
RFR_k = RFR(n_estimators=100,random_state=0).fit(Xtrain_new,Ytrain)

# %%
print(RFR_k.score(Xtrain_new,Ytrain))
print(RFR_k.score(Xtest_new,Ytest))
# Out:
# 0.9897459032724252
# 0.9277762959933884

# %%
RFR_k_1 = RFR(n_estimators=180,
            max_depth=20,
            random_state=0).fit(Xtrain_new,Ytrain)
print(RFR_k_1.score(Xtrain_new,Ytrain))
print(RFR_k_1.score(Xtest_new,Ytest))
# Out:
# 0.9413736983463231
# 0.8844483348708287

# %%
RFR_k = RFR(n_estimators=180,
            max_depth=25,
            random_state=0).fit(Xtrain_new,Ytrain)
print(RFR_k.score(Xtrain_new,Ytrain))
print(RFR_k.score(Xtest_new,Ytest))
# Out:
# 0.983599484568408
# 0.9226254557834114

# %%
weights =RFR_k.feature_importances_

# %%
df_cr = pd.DataFrame(dict(zip(col_k,weights)),index=['weights']).T.sort_values(by='weights')

# %%
plt.figure(figsize=(8,6))
plt.barh(df_cr.index,df_cr.values[:,0],label='weights')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend();

# %%
plt.figure(figsize=(8,6))
plt.barh(df_cr.index,df_cr.values[:,0],label='weights')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend();

# %%
time0 = time()
for i in np.arange(20, 31, 1):
    rfr = RFR(n_estimators= 180
             ,max_depth= i
             ,random_state=0)
    score_ = cross_val_score(rfr,Xtrain_new,Ytrain,cv=5).mean()
    score_2.append(score_)
print(datetime.datetime.fromtimestamp(time()-time0).strftime("%M:%S:%f"))
print('得分：',max(score_2),'最大深度：',np.arange(20, 31, 1)[np.argmax(score_2)])
plt.figure(figsize=(8,6))
plt.plot(np.arange(20, 31, 1),score_2)
plt.show();

#Y运行时间太久了，中断了
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-119-20c8840cd9db> in <module>
#       5              ,max_depth= i
#       6              ,random_state=0)
# ----> 7     score_ = cross_val_score(rfr,Xtrain_new,Ytrain,cv=5).mean()
#       8     score_2.append(score_)
#       9 print(datetime.datetime.fromtimestamp(time()-time0).strftime("%M:%S:%f"))
#
# D:\DataFrame\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     389                                 fit_params=fit_params,
#     390                                 pre_dispatch=pre_dispatch,
# --> 391                                 error_score=error_score)
#     392     return cv_results['test_score']
#     393
#
# D:\DataFrame\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     230             return_times=True, return_estimator=return_estimator,
#     231             error_score=error_score)
# --> 232         for train, test in cv.split(X, y, groups))
#     233
#     234     zipped_scores = list(zip(*scores))
#
# D:\DataFrame\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# D:\DataFrame\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# D:\DataFrame\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# D:\DataFrame\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# D:\DataFrame\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# D:\DataFrame\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# D:\DataFrame\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# D:\DataFrame\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     514             estimator.fit(X_train, **fit_params)
#     515         else:
# --> 516             estimator.fit(X_train, y_train, **fit_params)
#     517
#     518     except Exception as e:
#
# D:\DataFrame\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     328                     t, self, X, y, sample_weight, i, len(trees),
#     329                     verbose=self.verbose, class_weight=self.class_weight)
# --> 330                 for i, t in enumerate(trees))
#     331
#     332             # Collect newly grown trees
#
# D:\DataFrame\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# D:\DataFrame\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# D:\DataFrame\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# D:\DataFrame\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# D:\DataFrame\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# D:\DataFrame\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# D:\DataFrame\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# D:\DataFrame\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     116             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     117
# --> 118         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     119     else:
#     120         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# D:\DataFrame\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1155             sample_weight=sample_weight,
#    1156             check_input=check_input,
# -> 1157             X_idx_sorted=X_idx_sorted)
#    1158         return self
#    1159
#
# D:\DataFrame\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     378                                            min_impurity_split)
#     379
# --> 380         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     381
#     382         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
score_2.append
# Out:
# [0.8713423529273857,
#  0.8834327897962501,
#  0.8923107206761036,
#  0.899344869094968,
#  0.9039076126239]

# %%
plt.figure(figsize=(8,6))
plt.plot(np.arange(20, 25, 1),score_2)
plt.show();

# %% [markdown]
# 发现cityorders 与 cityuvs 高度相关

# %%
Xtrain_new.drop(columns='cityuvs',axis=1,inplace=True)
Xtest_new.drop(columns='cityuvs',axis=1,inplace=True)

# %%
Xtrain_new.to_csv('Xtrain_new.csv')
Xtest_new.to_csv('Xtest_new.csv')
Ytrain.to_csv('Ytrain.csv')
Ytest.to_csv('Ytest.csv')
# Out:
# D:\DataFrame\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\DataFrame\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   after removing the cwd from sys.path.
