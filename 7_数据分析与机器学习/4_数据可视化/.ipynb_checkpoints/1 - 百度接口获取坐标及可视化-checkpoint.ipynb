# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium
import numpy as np

# %%
# 读取数据
def read_data(path, encoding='utf-8'):
    df = pd.read_excel(path)
    return df

df = read_data(r"C:\Users\caoyuanyuan\Desktop\项目文档\Python脚本\file\WiFi位置.xlsx")
df.head(10)
# Out:
#                bssid                ssid        lat        lon
# 0  5e:5b:02:d3:cd:2a   OPPO Reno8 Pro 5G  43.289801  87.186405
# 1  5e:60:3b:94:b7:02              iPhone  43.515189  87.472951
# 2  00:e0:4c:1a:b7:72  AP_9J028E0GDA00009  43.440441  87.184338
# 3  5e:85:44:0c:04:ae               Ademi  43.465333  87.678045
# 4  00:e0:4c:2b:24:a7          2307173330  43.481497  87.670479
# 5  00:e0:4c:41:6c:9c          2307173388  43.473125  87.662942
# 6  00:e0:4c:7e:d4:52          2306133305  43.135091  87.080988
# 7  00:e0:4c:8a:9c:e5  AP_9J028E0GDA00027  43.467184  87.268078
# 8  00:e0:4c:a9:2e:a4          2307173829  43.464740  87.674108
# 9  5e:c1:07:0c:86:df              iPhone  43.750421  87.372879

# %%
fig = plt.figure(figsize=(10, 5))
plt.scatter(df['lat'], df['lon'], label='0')
plt.xlabel('wifi-lat')
plt.ylabel('wifi-lon')
# Out:
# Text(0, 0.5, 'wifi-lon')

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import math
from geopy.distance import geodesic

# %%
# # 计算两点之间的距离
def calculate_distance(point1, point2):
    distance = geodesic(point1, point2).km
    return distance
 
# 判断点是否孤立
def is_isolated(point, points_list, threshold):
    for other_point in points_list:
        if calculate_distance(point, other_point) < threshold:
            return False
    return True
 
# 示例使用
points = [(1, 2), (3, 4), (5, 6)]  # 一系列点的坐标
threshold = 2  # 定义孤立阈值：距离小于该值的点不被认为是孤立的
 
# 检查点(10, 10)是否孤立
point_to_check = (10, 10)
is_point_isolated = is_isolated(point_to_check, points, threshold)
 
print(is_point_isolated)  # 如果孤立，输出True；如果不孤立，输出False
# Out:
# True

# %% [markdown]
# ### 获取地理编码

# %%
# encoding:utf-8
import requests 

# 创建应用后获取的AK
ak = "X5WPPIRe8wRkLTGMJNntbuv7TPgNgjgo"
  
def get_location(address, ak):
    try:
        # 接口地址
        url = "https://api.map.baidu.com/geocoding/v3"
        params = {
            "address": address,
            "output": "json",
            "ak": ak,
        }
        response = requests.get(url=url, params=params)
        if response:
            result= response.json()
            if result['status'] == 0 and result['result']:
                lng = result['result']['location']['lng']
                lat = result['result']['location']['lat']
            return lng,lat
    except Exception as e:
        print(f"Failed to get location for {address}: {e}")
    return '', ''
        
        
if __name__ == '__main__':
    address = "上海市宝山区杨行镇招商海德名门"
    location = get_location(address, ak)
    print(location)
# Out:
# (121.42601881233438, 31.397008395501853)

# %% [markdown]
# ### 逆地理编码

# %%
# encoding:utf-8
import requests 

# 创建应用后获取的AK
ak = "X5WPPIRe8wRkLTGMJNntbuv7TPgNgjgo"
  
def get_address(location, ak):
    try:
        # 接口地址
        url = "https://api.map.baidu.com/reverse_geocoding/v3"
        params = {
            "ak": ak,
            "output": "json",
            "coordtype": "wgs84ll",
            "extensions_poi": "0",
            "location": location,
        }
        response = requests.get(url=url, params=params)
        if response:
            result= response.json()    
            if result['status'] == 0 and result['result']:
                address = result['result']['formatted_address']
                return address
    except Exception as e:
        print(f"Failed to get location for {location}: {e}")
    return ''
        
        
if __name__ == '__main__':
    location = '2.934692727275031,102.49259909090668'
    address = get_address(location, ak)
    print(address)
# Out:
# Jempol, Negeri Sembilan, Malaysia

# %% [markdown]
# ### Folium地图可视化

# %% [markdown]
# 参考网址：
#
# https://lbsyun.baidu.com/index.php?title=jspopular3.0/guide/show
#
# https://mp.weixin.qq.com/s?__biz=MzUzODA5MjM5NQ==&mid=2247495745&idx=1&sn=19a35e9a2e2e2198792c3c047a8280bb&chksm=fade4645cda9cf53fdb6a506085fef9a0619e4425248541de16f5630000afcfb24c5500413f2&cur_album_id=1961247446194257928&scene=189#wechat_redirect

# %% [markdown]
# #### 1、准备工作
# 本案例以高德地图为底图样式，经纬度也是基于高德地图下！

# %%
import folium.plugins as plugins
import folium

# %%
# 高德地图底片
tiles= 'https://wprd01.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7'

# 创建Map对象
m = folium.Map([40.003451,116.326398],
               tiles=tiles,
               attr='高德-常规图',
               zoom_start=15,
               control_scale=True,
               width='100%',
               height='100%'
              )

# 查看m的类型
m.__class__
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9cbf6fae522cc052c824d1e8a5e6764f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9cbf6fae522cc052c824d1e8a5e6764f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9cbf6fae522cc052c824d1e8a5e6764f = L.map(
#                 &quot;map_9cbf6fae522cc052c824d1e8a5e6764f&quot;,
#                 {
#                     center: [40.003451, 116.326398],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9cbf6fae522cc052c824d1e8a5e6764f);
#
#
#
#
#
#             var tile_layer_3f9777f2c2092a5e4965dc07c95315f7 = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_3f9777f2c2092a5e4965dc07c95315f7.addTo(map_9cbf6fae522cc052c824d1e8a5e6764f);
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 通过这样一个简单的例子，可以了解到，folium.Map()即为folium中绘制地图图层的基本函数，其主要参数如下：
#
# - location：tuple或list类型输入，用于控制初始地图中心店的坐标，格式为（纬度，经度）或 [纬度，经度]，默认为None
# - width：int型或str型,int型时，传入的是地图宽度的像素值；str型时，传入的是地图宽度的百分比，默认为"xx%"，默认为"100%"
# - height：控制地图的高度，格式等同width
# - tiles：str型，用于控制绘图调用的地图样式，默认为"OpenStreetMap"，也有一些其他的内建地图样式，如"stamen Terrain"、"Stamen Toner"、"mapbox Bright"、"Mapbox Control Romm"等；也可以传入"None"来绘制一个没有风格的朴素地图，或传入一个URL来使用其它自选的osm
# - max_zoom：int型，控制地图可以放大程度的上限，默认为18
# - attr：str型，当在tiles中使用自选URL内的osm时使用，用于给自选osm命名
# - control_scale：bool型，控制是否在地图上添加比例尺，默认为False即不添加
# - non_touch：bool型，控制地图是否禁止接受来自设备的触控事件譬如拖拽等，默认为False，即不禁止

# %% [markdown]
# #### 2、标记点
# 标记点就是在地图是标记出某经纬度所在的位置，使用的是函数方法folium.Marker()。
#
# 其主要参数如下：
# - location：经纬度列表
# - popup：str型或folium.Popup()对象输入，用于控制标记部件的具体样式（folium内部自建了许多样式），默认为None，即不显示部件
# - tooltip：鼠标移动到标记点时弹出的提示
# - icon：folium.Icon()对象，用于设置popup定义的部件的具体颜色、图标内容等,比如cloud、cny与info-sign等
# - iconcolor：标记图案颜色

# %%
tooltip = "点我"
folium.Marker(
    location = [40.003451,116.326398],
    tooltip = tooltip,
    popup = "清华大学",
    
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9cbf6fae522cc052c824d1e8a5e6764f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9cbf6fae522cc052c824d1e8a5e6764f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9cbf6fae522cc052c824d1e8a5e6764f = L.map(
#                 &quot;map_9cbf6fae522cc052c824d1e8a5e6764f&quot;,
#                 {
#                     center: [40.003451, 116.326398],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9cbf6fae522cc052c824d1e8a5e6764f);
#
#
#
#
#
#             var tile_layer_3f9777f2c2092a5e4965dc07c95315f7 = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_3f9777f2c2092a5e4965dc07c95315f7.addTo(map_9cbf6fae522cc052c824d1e8a5e6764f);
#
#             var marker_2322570231802cceb7482733eabf1380 = L.marker(
#                 [40.003451, 116.326398],
#                 {}
#             ).addTo(map_9cbf6fae522cc052c824d1e8a5e6764f);
#
#
#         var popup_8df9cd8ecbc2e171bce1fe9bb38acc6d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_98170ef5b9d888275341db2c52a31382 = $(`&lt;div id=&quot;html_98170ef5b9d888275341db2c52a31382&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;清华大学&lt;/div&gt;`)[0];
#                 popup_8df9cd8ecbc2e171bce1fe9bb38acc6d.setContent(html_98170ef5b9d888275341db2c52a31382);
#
#
#
#         marker_2322570231802cceb7482733eabf1380.bindPopup(popup_8df9cd8ecbc2e171bce1fe9bb38acc6d)
#         ;
#
#
#
#
#             marker_2322570231802cceb7482733eabf1380.bindTooltip(
#                 `&lt;div&gt;
#                      点我
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 有朋友可能会说，点击标记点的提示内容怎么是竖着显示的呀，要是太长的话不久太长了！！当然，我们可以通过设置参数max_width来解决这个问题，让文本信息横向显示~

# %%
tooltip = "点我"
folium.Marker(
    location = [40.003451,116.326398],
    tooltip = tooltip,
    popup = folium.Popup("清华大学", max_width=10)
    
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9cbf6fae522cc052c824d1e8a5e6764f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9cbf6fae522cc052c824d1e8a5e6764f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9cbf6fae522cc052c824d1e8a5e6764f = L.map(
#                 &quot;map_9cbf6fae522cc052c824d1e8a5e6764f&quot;,
#                 {
#                     center: [40.003451, 116.326398],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9cbf6fae522cc052c824d1e8a5e6764f);
#
#
#
#
#
#             var tile_layer_3f9777f2c2092a5e4965dc07c95315f7 = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_3f9777f2c2092a5e4965dc07c95315f7.addTo(map_9cbf6fae522cc052c824d1e8a5e6764f);
#
#             var marker_2322570231802cceb7482733eabf1380 = L.marker(
#                 [40.003451, 116.326398],
#                 {}
#             ).addTo(map_9cbf6fae522cc052c824d1e8a5e6764f);
#
#
#         var popup_8df9cd8ecbc2e171bce1fe9bb38acc6d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_98170ef5b9d888275341db2c52a31382 = $(`&lt;div id=&quot;html_98170ef5b9d888275341db2c52a31382&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;清华大学&lt;/div&gt;`)[0];
#                 popup_8df9cd8ecbc2e171bce1fe9bb38acc6d.setContent(html_98170ef5b9d888275341db2c52a31382);
#
#
#
#         marker_2322570231802cceb7482733eabf1380.bindPopup(popup_8df9cd8ecbc2e171bce1fe9bb38acc6d)
#         ;
#
#
#
#
#             marker_2322570231802cceb7482733eabf1380.bindTooltip(
#                 `&lt;div&gt;
#                      点我
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f14896ee3974fc51ff47368860bb7b16 = L.marker(
#                 [40.003451, 116.326398],
#                 {}
#             ).addTo(map_9cbf6fae522cc052c824d1e8a5e6764f);
#
#
#         var popup_a7ebbbdb4206c642a5efba110c7c93be = L.popup({&quot;maxWidth&quot;: 10});
#
#
#
#                 var html_91cfae0f37b7c475be6df93a7357cfc2 = $(`&lt;div id=&quot;html_91cfae0f37b7c475be6df93a7357cfc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;清华大学&lt;/div&gt;`)[0];
#                 popup_a7ebbbdb4206c642a5efba110c7c93be.setContent(html_91cfae0f37b7c475be6df93a7357cfc2);
#
#
#
#         marker_f14896ee3974fc51ff47368860bb7b16.bindPopup(popup_a7ebbbdb4206c642a5efba110c7c93be)
#         ;
#
#
#
#
#             marker_f14896ee3974fc51ff47368860bb7b16.bindTooltip(
#                 `&lt;div&gt;
#                      点我
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 不同的标记点样式
folium.Marker(
    [40.001528,116.32408], 
    popup="第一教学楼",
    icon=folium.Icon(icon="cloud", icon_color='yellow'),
).add_to(m)

folium.Marker(
    [39.998586,116.328908], 
    popup=folium.Popup("纳米科技楼", max_width=100),
    icon=folium.Icon(color="green", icon="cny"),
).add_to(m)

folium.Marker(
    location=[40.005251,116.322299],
    popup="体育场",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bab83bb52bae054b9464252e9d4b5e72 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bab83bb52bae054b9464252e9d4b5e72&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bab83bb52bae054b9464252e9d4b5e72 = L.map(
#                 &quot;map_bab83bb52bae054b9464252e9d4b5e72&quot;,
#                 {
#                     center: [40.003451, 116.326398],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_bab83bb52bae054b9464252e9d4b5e72);
#
#
#
#
#
#             var tile_layer_ad5e3a0eb83fa51579ecc31053154529 = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_ad5e3a0eb83fa51579ecc31053154529.addTo(map_bab83bb52bae054b9464252e9d4b5e72);
#
#             var marker_fae34bd49e563cda0d2f590934cc9823 = L.marker(
#                 [40.003451, 116.326398],
#                 {}
#             ).addTo(map_bab83bb52bae054b9464252e9d4b5e72);
#
#
#         var popup_23481957cfe16f1507cc3f858a5b2738 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4047f897f58a6dcee6bf4c9693fa32c8 = $(`&lt;div id=&quot;html_4047f897f58a6dcee6bf4c9693fa32c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;清华大学&lt;/div&gt;`)[0];
#                 popup_23481957cfe16f1507cc3f858a5b2738.setContent(html_4047f897f58a6dcee6bf4c9693fa32c8);
#
#
#
#         marker_fae34bd49e563cda0d2f590934cc9823.bindPopup(popup_23481957cfe16f1507cc3f858a5b2738)
#         ;
#
#
#
#
#             marker_fae34bd49e563cda0d2f590934cc9823.bindTooltip(
#                 `&lt;div&gt;
#                      点我
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8f65ffb313926baf28c17e335adfb567 = L.marker(
#                 [40.003451, 116.326398],
#                 {}
#             ).addTo(map_bab83bb52bae054b9464252e9d4b5e72);
#
#
#         var popup_34a0e6ee1395ddc95eb2a06d0bde25cd = L.popup({&quot;maxWidth&quot;: 10});
#
#
#
#                 var html_1fa96e24214ec8e5fd3baba0c0df3d9a = $(`&lt;div id=&quot;html_1fa96e24214ec8e5fd3baba0c0df3d9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;清华大学&lt;/div&gt;`)[0];
#                 popup_34a0e6ee1395ddc95eb2a06d0bde25cd.setContent(html_1fa96e24214ec8e5fd3baba0c0df3d9a);
#
#
#
#         marker_8f65ffb313926baf28c17e335adfb567.bindPopup(popup_34a0e6ee1395ddc95eb2a06d0bde25cd)
#         ;
#
#
#
#
#             marker_8f65ffb313926baf28c17e335adfb567.bindTooltip(
#                 `&lt;div&gt;
#                      点我
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9d6ba02fa09e06e8ac2754e805d66c8b = L.marker(
#                 [40.001528, 116.32408],
#                 {}
#             ).addTo(map_bab83bb52bae054b9464252e9d4b5e72);
#
#
#             var icon_5c8eb96d624b41d8c00c2e59e2242576 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;yellow&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9d6ba02fa09e06e8ac2754e805d66c8b.setIcon(icon_5c8eb96d624b41d8c00c2e59e2242576);
#
#
#         var popup_0cbd63cffb91b1f7af882512a206dfe9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5ab80449f30cfe78b07eda0557dc1efd = $(`&lt;div id=&quot;html_5ab80449f30cfe78b07eda0557dc1efd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;第一教学楼&lt;/div&gt;`)[0];
#                 popup_0cbd63cffb91b1f7af882512a206dfe9.setContent(html_5ab80449f30cfe78b07eda0557dc1efd);
#
#
#
#         marker_9d6ba02fa09e06e8ac2754e805d66c8b.bindPopup(popup_0cbd63cffb91b1f7af882512a206dfe9)
#         ;
#
#
#
#
#             var marker_91784fa41c4142e7e3b38c52b53c1e9f = L.marker(
#                 [39.998586, 116.328908],
#                 {}
#             ).addTo(map_bab83bb52bae054b9464252e9d4b5e72);
#
#
#             var icon_60705fa662ec192bc8117f40beaca20f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cny&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_91784fa41c4142e7e3b38c52b53c1e9f.setIcon(icon_60705fa662ec192bc8117f40beaca20f);
#
#
#         var popup_48baf24e1fc042e53266008549d5d5f8 = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_1b8d721b40c46d5cb348e74b1f17a152 = $(`&lt;div id=&quot;html_1b8d721b40c46d5cb348e74b1f17a152&qu

# %% [markdown]
# #### 3、标记圆形区域
#
# 标记圆形区域有两种操作，分别是Circle和CircleMarker，后者是一个始终与整个Map保持相对尺寸的Circle。
#
# 区别于Circle就是Circle是绝对尺寸（以m为单位），当你放大地图时Circle会变小，因为它与地图的相对尺寸变小了；而CircleMarker不论你怎么缩放地图，它在地图都始终是那么大。
#
# 在folium中我们使用folium.Circle()来绘制指定圆心和半径的圆圈，其主要参数如下：
#
# - location：同folium.Map()中的location，用于控制圆圈的圆心坐标
# - radius：int型，用于控制圆圈的半径，单位米，注意，在folium.Circle()中，radius因为半径的单位是米，所以其大小随着我们对地图的缩放程度而进行相应的变化，但在与folium.CircleMarker()方法中的radius参数单位为像素，即其为屏幕上大小固定的一个圆圈，随着地图的缩放，其大小也不会发生变化
# - color：str型，用于控制圆圈的颜色，默认为十六进制颜色’#3388ff’，即一种蓝色
# - fill：bool型，当为True时，圆圈内部将被填充上色彩，默认不填充
# - fill_color：str型，控制圆圈内部填充的色彩，默认与color参数一致
# - fill_opacity：float型，用于控制圆圈内部填充颜色的透明度，从0.到1.之间，默认为0.2
# - popup：str型或folium.Popup()对象，用于控制圆圈的样式，默认为None，即无样式

# %%
m = folium.Map([40.003451,116.326398],
               tiles=tiles,
               attr='高德-常规图',
               zoom_start=15,
               control_scale=True,
               width='100%',
               height='100%'
              )
# 标记点
folium.Marker(
    location = [40.003451,116.326398],
    popup="体育中心",
)

# 标记圆形区域
folium.Circle(
    radius = 50,
    location = [40.003451,116.326398],
    popup="西区体育馆",
    color="crimson",
    fill=False,
).add_to(m)

folium.CircleMarker(
    location=[40.004404,116.33239],
    radius=20,
    popup="体育中心",
    color="Blue",
    fill=True,
    fill_color="#3186cc",
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2d8f5c9d0e923332d954c66c6020d84 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2d8f5c9d0e923332d954c66c6020d84&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2d8f5c9d0e923332d954c66c6020d84 = L.map(
#                 &quot;map_b2d8f5c9d0e923332d954c66c6020d84&quot;,
#                 {
#                     center: [40.003451, 116.326398],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b2d8f5c9d0e923332d954c66c6020d84);
#
#
#
#
#
#             var tile_layer_4730136faa11ff5debb8f5d99966e8cd = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_4730136faa11ff5debb8f5d99966e8cd.addTo(map_b2d8f5c9d0e923332d954c66c6020d84);
#
#             var circle_79274e8313f6ffb5ebfdde0b1c2c9d3b = L.circle(
#                 [40.003451, 116.326398],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b2d8f5c9d0e923332d954c66c6020d84);
#
#
#         var popup_eaa928a6c0feef9780357b725447773a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af56ee297e9f957da675a5525d2dc3a2 = $(`&lt;div id=&quot;html_af56ee297e9f957da675a5525d2dc3a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;西区体育馆&lt;/div&gt;`)[0];
#                 popup_eaa928a6c0feef9780357b725447773a.setContent(html_af56ee297e9f957da675a5525d2dc3a2);
#
#
#
#         circle_79274e8313f6ffb5ebfdde0b1c2c9d3b.bindPopup(popup_eaa928a6c0feef9780357b725447773a)
#         ;
#
#
#
#
#             var circle_marker_148071b6a4f54840e576dcccc1b1e512 = L.circleMarker(
#                 [40.004404, 116.33239],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;Blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b2d8f5c9d0e923332d954c66c6020d84);
#
#
#         var popup_7e0a827bc9454b97da5e822b39efcd77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5526f21f025c89ee94d4f0619e453187 = $(`&lt;div id=&quot;html_5526f21f025c89ee94d4f0619e453187&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;体育中心&lt;/div&gt;`)[0];
#                 popup_7e0a827bc9454b97da5e822b39efcd77.setContent(html_5526f21f025c89ee94d4f0619e453187);
#
#
#
#         circle_marker_148071b6a4f54840e576dcccc1b1e512.bindPopup(popup_7e0a827bc9454b97da5e822b39efcd77)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 4、标记连线
#
# 标记连线就比较简单了，就是按照给到的经纬度坐标点依次连线呗，咱们可以应用在比如知道了导航路径的经纬度列表，然后在地图上绘制导航路径之类的。这里用到的是函数方法PolyLine，具体大家看下面效果感受一下！
#
# folium.PolyLine()的常用参数如下：
# - locations：二级嵌套的list，用于指定需要按顺序连接的坐标点，若要绘制闭合的几何图像，需要在传入列表的首尾传入同样的坐标
# - color：str型，传入十六进制的颜色，用于控制线条的颜色，默认为’#03f’
# - weight：float型，用于控制线条的宽度，默认为5
# - opacity：float型，用于控制线条的透明度，默认为0.5
# - popup：str型或folium.Popup()对象，用于控制线条样式

# %%
folium.Map(
    location = [40.003451,116.326398],
    tiles = tiles,
    attr = "高德-常规图",
    zoom_start = 15,
    control_scale = False,
    width='100%',
    height='100%'
)

# 标记坐标点连线
folium.PolyLine(
    locations = [       
        [39.998586,116.328908],
        [40.001528,116.32408],
        [40.005251,116.322299],
    ],
    popup = folium.Popup("标记坐标点之间连线", max_width=200),
    color = "red"
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2d8f5c9d0e923332d954c66c6020d84 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2d8f5c9d0e923332d954c66c6020d84&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2d8f5c9d0e923332d954c66c6020d84 = L.map(
#                 &quot;map_b2d8f5c9d0e923332d954c66c6020d84&quot;,
#                 {
#                     center: [40.003451, 116.326398],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b2d8f5c9d0e923332d954c66c6020d84);
#
#
#
#
#
#             var tile_layer_4730136faa11ff5debb8f5d99966e8cd = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_4730136faa11ff5debb8f5d99966e8cd.addTo(map_b2d8f5c9d0e923332d954c66c6020d84);
#
#             var circle_79274e8313f6ffb5ebfdde0b1c2c9d3b = L.circle(
#                 [40.003451, 116.326398],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b2d8f5c9d0e923332d954c66c6020d84);
#
#
#         var popup_eaa928a6c0feef9780357b725447773a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af56ee297e9f957da675a5525d2dc3a2 = $(`&lt;div id=&quot;html_af56ee297e9f957da675a5525d2dc3a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;西区体育馆&lt;/div&gt;`)[0];
#                 popup_eaa928a6c0feef9780357b725447773a.setContent(html_af56ee297e9f957da675a5525d2dc3a2);
#
#
#
#         circle_79274e8313f6ffb5ebfdde0b1c2c9d3b.bindPopup(popup_eaa928a6c0feef9780357b725447773a)
#         ;
#
#
#
#
#             var circle_marker_148071b6a4f54840e576dcccc1b1e512 = L.circleMarker(
#                 [40.004404, 116.33239],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;Blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b2d8f5c9d0e923332d954c66c6020d84);
#
#
#         var popup_7e0a827bc9454b97da5e822b39efcd77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5526f21f025c89ee94d4f0619e453187 = $(`&lt;div id=&quot;html_5526f21f025c89ee94d4f0619e453187&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;体育中心&lt;/div&gt;`)[0];
#                 popup_7e0a827bc9454b97da5e822b39efcd77.setContent(html_5526f21f025c89ee94d4f0619e453187);
#
#
#
#         circle_marker_148071b6a4f54840e576dcccc1b1e512.bindPopup(popup_7e0a827bc9454b97da5e822b39efcd77)
#         ;
#
#
#
#
#             var poly_line_74e05032bc9f41a69037a12a9e699a28 = L.polyline(
#                 [[39.998586, 116.328908], [40.001528, 116.32408], [40.005251, 116.322299]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b2d8f5c9d0e923332d954c66c6020d84);
#
#
#         var popup_2bb2faf1e938f9ebc5076df29c0af81a = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_7a290da0d914f3e1b0719d4092b1f2b2 = $(`&lt;div id=&quot;html_7a290da0d914f3e1b0719d4092b1f2b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;标记坐标点之间连线&lt;/div&gt;`)[0];
#                 popup_2bb2faf1e938f9ebc5076df29c0af81a.setContent(html_7a290da0d914f3e1b0719d4092b1f2b2);
#
#
#
#         poly_line_74e05032bc9f41a69037a12a9e699a28.bindPopup(popup_2bb2faf1e938f9ebc5076df29c0af81a)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 5、标记区域

# %%
# 标记区域
m = folium.Map([40.003451,116.326398],
               tiles= tiles,
               attr='高德-常规图',
               zoom_start=15,
               control_scale=True,
               width='100%'
              )
folium.Polygon(
    locations=[
        [39.998586,116.328908],
        [40.001528,116.32408],
        [40.005251,116.322299],
    ],
    popup=folium.Popup('标记坐标点之间多边形区域', max_width=200),
    color='blue',    # 线颜色
    fill=True,      # 是否填充
    weight=3,       # 边界线宽
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44072c7cbca9c888278f4c401edeed43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44072c7cbca9c888278f4c401edeed43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44072c7cbca9c888278f4c401edeed43 = L.map(
#                 &quot;map_44072c7cbca9c888278f4c401edeed43&quot;,
#                 {
#                     center: [40.003451, 116.326398],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_44072c7cbca9c888278f4c401edeed43);
#
#
#
#
#
#             var tile_layer_4f204c2e45b03f7a470bb1e26fc1ff78 = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_4f204c2e45b03f7a470bb1e26fc1ff78.addTo(map_44072c7cbca9c888278f4c401edeed43);
#
#             var polygon_c4b392d5926131d73cc848594522cb65 = L.polygon(
#                 [[39.998586, 116.328908], [40.001528, 116.32408], [40.005251, 116.322299]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_44072c7cbca9c888278f4c401edeed43);
#
#
#         var popup_642ccad2984f41cdaf4df2dba37b2552 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_187858dffc89ab0a7b543529596dc5ae = $(`&lt;div id=&quot;html_187858dffc89ab0a7b543529596dc5ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;标记坐标点之间多边形区域&lt;/div&gt;`)[0];
#                 popup_642ccad2984f41cdaf4df2dba37b2552.setContent(html_187858dffc89ab0a7b543529596dc5ae);
#
#
#
#         polygon_c4b392d5926131d73cc848594522cb65.bindPopup(popup_642ccad2984f41cdaf4df2dba37b2552)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 6、鼠标点击事件
# 鼠标点击事件顾名思义即可，这里将演示两种：点击显示经纬度、点击进行标记点。用add_child来添加这类事件插件！

# %% [markdown]
# #### 点击显示经纬度

# %%
# 添加点击触发事件
m = folium.Map([40.003451,116.326398],
               tiles= tiles,
               attr='高德-常规图',
               zoom_start=15,
               control_scale=True,
               width='100%'
              )

# 点击显示经纬度
m.add_child(folium.LatLngPopup())     
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ff5461d85c68fa9824d386cb04d6661 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ff5461d85c68fa9824d386cb04d6661&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ff5461d85c68fa9824d386cb04d6661 = L.map(
#                 &quot;map_3ff5461d85c68fa9824d386cb04d6661&quot;,
#                 {
#                     center: [40.003451, 116.326398],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3ff5461d85c68fa9824d386cb04d6661);
#
#
#
#
#
#             var tile_layer_a8fda733c4a9e3039afce756fca16cb9 = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_a8fda733c4a9e3039afce756fca16cb9.addTo(map_3ff5461d85c68fa9824d386cb04d6661);
#
#                 var lat_lng_popup_8c4983898da4857d584b79b688a43cbc = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_8c4983898da4857d584b79b688a43cbc
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_3ff5461d85c68fa9824d386cb04d6661);
#                     }
#                 map_3ff5461d85c68fa9824d386cb04d6661.on(&#x27;click&#x27;, latLngPop);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 点击进行标记点

# %%
# 点击显示标记点
m.add_child(folium.ClickForMarker(popup="选中的点"))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ff5461d85c68fa9824d386cb04d6661 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ff5461d85c68fa9824d386cb04d6661&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ff5461d85c68fa9824d386cb04d6661 = L.map(
#                 &quot;map_3ff5461d85c68fa9824d386cb04d6661&quot;,
#                 {
#                     center: [40.003451, 116.326398],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3ff5461d85c68fa9824d386cb04d6661);
#
#
#
#
#
#             var tile_layer_a8fda733c4a9e3039afce756fca16cb9 = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_a8fda733c4a9e3039afce756fca16cb9.addTo(map_3ff5461d85c68fa9824d386cb04d6661);
#
#                 var lat_lng_popup_8c4983898da4857d584b79b688a43cbc = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_8c4983898da4857d584b79b688a43cbc
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_3ff5461d85c68fa9824d386cb04d6661);
#                     }
#                 map_3ff5461d85c68fa9824d386cb04d6661.on(&#x27;click&#x27;, latLngPop);
#
#
#                 function newMarker(e){
#                     var new_mark = L.marker().setLatLng(e.latlng).addTo(map_3ff5461d85c68fa9824d386cb04d6661);
#                     new_mark.dragging.enable();
#                     new_mark.on(&#x27;dblclick&#x27;, function(e){ map_3ff5461d85c68fa9824d386cb04d6661.removeLayer(e.target)})
#                     var lat = e.latlng.lat.toFixed(4),
#                        lng = e.latlng.lng.toFixed(4);
#                     new_mark.bindPopup(`选中的点`);
#                     };
#                 map_3ff5461d85c68fa9824d386cb04d6661.on(&#x27;click&#x27;, newMarker);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 7、鼠标操作标记
# 其实，以上的各种操作还可以通过鼠标来一一操作，需要调用plugins.Draw()对象来完成~

# %%
# 鼠标操作绘制地图标记
m = folium.Map([40.003451,116.326398],
               tiles= tiles,
               attr='高德-常规图',
               zoom_start=15,
               control_scale=True,
               width='100%'
              )
draw = plugins.Draw()
draw.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb1b1bad977ee4cad6afbb81ac8c6113 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb1b1bad977ee4cad6afbb81ac8c6113&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb1b1bad977ee4cad6afbb81ac8c6113 = L.map(
#                 &quot;map_fb1b1bad977ee4cad6afbb81ac8c6113&quot;,
#                 {
#                     center: [40.003451, 116.326398],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_fb1b1bad977ee4cad6afbb81ac8c6113);
#
#
#
#
#
#             var tile_layer_a0581971aa2adfc3c77cc5a753aabf8d = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_a0581971aa2adfc3c77cc5a753aabf8d.addTo(map_fb1b1bad977ee4cad6afbb81ac8c6113);
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_77256a5b240819df8409408b95d6baa9 = new L.featureGroup().addTo(
#                 map_fb1b1bad977ee4cad6afbb81ac8c6113
#             );
#             options.edit.featureGroup = drawnItems_draw_control_77256a5b240819df8409408b95d6baa9;
#             var draw_control_77256a5b240819df8409408b95d6baa9 = new L.Control.Draw(
#                 options
#             ).addTo( map_fb1b1bad977ee4cad6afbb81ac8c6113 );
#             map_fb1b1bad977ee4cad6afbb81ac8c6113.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_77256a5b240819df8409408b95d6baa9.addLayer(layer);
#              });
#             map_fb1b1bad977ee4cad6afbb81ac8c6113.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_77256a5b240819df8409408b95d6baa9.addLayer(e.layer);
#             });
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 8、双地图
#
# 双地图就是同时演示两张地图的操作，这里呢我们可以同时显示常规地图和卫星地图，或者别的需求！

# %%
m = folium.plugins.DualMap([40.003451,116.326398],
                           tiles= tiles,
                           attr='高德-常规图',
                           zoom_start=15,
                           control_scale=True,
              )
folium.TileLayer().add_to(m.m1)
tiles1 = 'https://webst02.is.autonavi.com/appmaptile?style=6&x={x}&y={y}&z={z}'
folium.TileLayer(tiles1,attr='高德卫星地图').add_to(m.m2)
folium.LayerControl(collapsed=True).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9f9c3758acf224316ac8f146f534389 {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01aa4d5e19e549e51eca470daf6f30c3 {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 100.0%;
#                     left: 50.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/jieter/Leaflet.Sync/L.Map.Sync.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9f9c3758acf224316ac8f146f534389&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01aa4d5e19e549e51eca470daf6f30c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9f9c3758acf224316ac8f146f534389 = L.map(
#                 &quot;map_a9f9c3758acf224316ac8f146f534389&quot;,
#                 {
#                     center: [40.003451, 116.326398],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_a9f9c3758acf224316ac8f146f534389);
#
#
#
#
#
#             var tile_layer_d586f97ce81b86b5ff06b0d365e898f4 = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_d586f97ce81b86b5ff06b0d365e898f4.addTo(map_a9f9c3758acf224316ac8f146f534389);
#
#             var tile_layer_1a4c18b49fa0d23c3121f4f6b6fe72ba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_1a4c18b49fa0d23c3121f4f6b6fe72ba.addTo(map_a9f9c3758acf224316ac8f146f534389);
#
#             var layer_control_fe5e50cc956877ac7b499e2b2cdaf9a1_layers = {
#                 base_layers : {
#                     &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot; : tile_layer_d586f97ce81b86b5ff06b0d365e898f4,
#                     &quot;openstreetmap&quot; : tile_layer_1a4c18b49fa0d23c3121f4f6b6fe72ba,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_fe5e50cc956877ac7b499e2b2cdaf9a1 = L.control.layers(
#                 layer_control_fe5e50cc956877ac7b499e2b2cdaf9a1_layers.base_layers,
#                 layer_control_fe5e50cc956877ac7b499e2b2cdaf9a1_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_a9f9c3758acf224316ac8f146f534389);
#
#
#
#             var map_01aa4d5e19e549e51eca470daf6f30c3 = L.map(
#                 &quot;map_01aa4d5e19e549e51eca470daf6f30c3&quot;,
#                 {
#                     center: [40.003451, 116.326398],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_01aa4d5e19e549e51eca470daf6f30c3);
#
#
#
#
#
#             var tile_layer_1012ccb994674ff432108b2e637b4f95 = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_1012ccb994674ff432108b2e637b4f95.addTo(map_01aa4d5e19e549e51eca470daf6f30c3);
#
#             var tile_layer_fa46a650caa705dca0b0c138a163614a = L.tileLayer(
#                 &quot;https://webst02.is.autonavi.com/appmaptile?style=6\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7\u536b\u661f\u5730\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;:

# %% [markdown]
# 我们也可以通过双地图发现在不同的地图瓦片样式下，经纬度存在一定的偏移，比如默认内置图和高德地图就有比较明显的区别。

# %% [markdown]
# #### 9、测距与面积
#
# 在folium绘制的地图中，其实还提供了测距与测算面积的小插件，点点鼠标就可以完成，直呼666~

# %%
m = folium.Map([40.003451,116.326398],
               tiles= tiles,
               attr='高德-常规图',
               zoom_start=15,
               control_scale=True,
               width='100%'
              )
m.add_child(plugins.MeasureControl())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e9d7c96f15c6810335c068cfea55941 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e9d7c96f15c6810335c068cfea55941&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e9d7c96f15c6810335c068cfea55941 = L.map(
#                 &quot;map_2e9d7c96f15c6810335c068cfea55941&quot;,
#                 {
#                     center: [40.003451, 116.326398],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2e9d7c96f15c6810335c068cfea55941);
#
#
#
#
#
#             var tile_layer_d0ebca3fc48711c03c0d299b230f290a = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_d0ebca3fc48711c03c0d299b230f290a.addTo(map_2e9d7c96f15c6810335c068cfea55941);
#
#             var measure_control_ef634a9e0dff0381b601399fca83753e = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;topright&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_2e9d7c96f15c6810335c068cfea55941.addControl(measure_control_ef634a9e0dff0381b601399fca83753e);
#
#             // Workaround for using this plugin with Leaflet&gt;=1.8.0
#             // https://github.com/ljagis/leaflet-measure/issues/171
#             L.Control.Measure.include({
#                 _setCaptureMarkerIcon: function () {
#                     // disable autopan
#                     this._captureMarker.options.autoPanOnFocus = false;
#                     // default function
#                     this._captureMarker.setIcon(
#                         L.divIcon({
#                             iconSize: this._map.getSize().multiplyBy(2)
#                         })
#                     );
#                 },
#             });
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
